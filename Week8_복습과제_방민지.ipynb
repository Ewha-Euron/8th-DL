# %% [markdown]
# # **U-Net 모델 구현**
#
# ✅ 아래 코드는 PyTorch로 작성한 간단한 U-Net 모델입니다.
#
# ✅ 주요 목표: 작은 이미지 세트로 segmentation 학습을 테스트하기!
#
# ✅ 특징: 업샘플링(deconv/upsample 선택 가능), 입력 스케일링, Gaussian noise 추가, 배치 정규화 적용

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset

# --- 작은 U-Net 정의 ---
class UNetSmall(nn.Module):
    def __init__(self, upsample_mode='deconv', net_scaling=None, edge_crop=0, gaussian_noise_std=0.1):
        super().__init__()
        self.net_scaling = net_scaling
        self.edge_crop = edge_crop
        self.gaussian_noise_std = gaussian_noise_std
        self.upsample_mode = upsample_mode

         # Convolution Block: Conv -> ReLU -> Conv -> ReLU
        def conv_block(in_c, out_c):
            return nn.Sequential(
                nn.Conv2d(in_c, out_c, kernel_size=3, padding=1),
                nn.ReLU(inplace=True),
                nn.Conv2d(out_c, out_c, kernel_size=3, padding=1),
                nn.ReLU(inplace=True)
            )

        # 인코더 부분 목표 -> 128 까지!
        self.enc1 = conv_block(3, 16)
        self.enc2 = conv_block(16, 32)
        self.enc3 = conv_block(32, 64)
        self.enc4 = conv_block(64, 128)
        # Bottleneck
        self.center = conv_block(128, 128)
        self.pool = nn.MaxPool2d(2)


        # 업샘플링 부분 정의 (deconv 또는 upsample+conv) 로
        if upsample_mode == 'deconv':
            def upsample_layer(in_c, out_c):
                return nn.ConvTranspose2d(in_c, out_c, kernel_size=2, stride=2)
        else:
            def upsample_layer(in_c, out_c):
                return nn.Sequential(
                    nn.Upsample(scale_factor=2, mode='nearest'),
                    nn.Conv2d(in_c, out_c, kernel_size=1)
                )
        # 디코더 부분
        self.up4 = upsample_layer(128, 128)
        self.dec4 = conv_block(128+128, 64)
        self.up3 = upsample_layer(64, 64)
        self.dec3 = conv_block(64+64, 32)
        self.up2 = upsample_layer(32, 32)
        self.dec2 = conv_block(32+32, 16)
        self.up1 = upsample_layer(16, 16)
        self.dec1 = conv_block(16+16, 16)

        # 최종 출력: 1채널(segmentation mask)
        self.final = nn.Conv2d(16, 1, kernel_size=1)

    def forward(self, x):
        if self.net_scaling:
        # 입력 스케일링
            x = F.avg_pool2d(x, self.net_scaling)
        # Gaussian noise 추가
        if self.gaussian_noise_std:
            noise = torch.randn_like(x) * self.gaussian_noise_std
            x = x + noise

        # 배치 정규화 적용
        x = F.batch_norm(x, running_mean=None, running_var=None, training=True)

        # 인코더
        e1 = self.enc1(x)
        e2 = self.enc2(self.pool(e1))
        e3 = self.enc3(self.pool(e2))
        e4 = self.enc4(self.pool(e3))
        # Bottleneck
        center = self.center(self.pool(e4))

        # 디코더 + Skip Connection
        d4 = self.up4(center)
        d4 = torch.cat([d4, e4], dim=1)
        d4 = self.dec4(d4)

        d3 = self.up3(d4)
        d3 = torch.cat([d3, e3], dim=1)
        d3 = self.dec3(d3)

        d2 = self.up2(d3)
        d2 = torch.cat([d2, e2], dim=1)
        d2 = self.dec2(d2)

        d1 = self.up1(d2)
        d1 = torch.cat([d1, e1], dim=1)
        d1 = self.dec1(d1)

        out = self.final(d1)
        out = torch.sigmoid(out)
         # Crop + Pad
        if self.edge_crop > 0:
            out = out[:, :, self.edge_crop:-self.edge_crop, self.edge_crop:-self.edge_crop]
            out = F.pad(out, (self.edge_crop, self.edge_crop, self.edge_crop, self.edge_crop))
        # Upsample 다시 확대
        if self.net_scaling:
            out = F.interpolate(out, scale_factor=self.net_scaling, mode='nearest')

        return out

# %% [markdown]
# ## **학습용 데이터 생성하기**

# %%
batch_size = 32
x = torch.randn(batch_size, 3, 128, 128)  # RGB 이미지
y = (torch.rand(batch_size, 1, 128, 128) > 0.5).float()  # 랜덤 이진 마스크

dataset = TensorDataset(x, y)
loader = DataLoader(dataset, batch_size=2, shuffle=True)

# %% [markdown]
# ## **데이터 시각화**

# %%
import matplotlib.pyplot as plt
# 첫 번째 이미지를 시각화
sample_x = x[0]
sample_y = y[0]

plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.imshow(sample_x.permute(1, 2, 0).numpy())
plt.title('Input Image')

plt.subplot(1, 2, 2)
plt.imshow(sample_y.squeeze().numpy(), cmap='gray')
plt.title('Ground Truth Mask')
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-3.8868513..4.236456].

# %% [markdown]
# ## **모델 선언 및 학습**

# %%
# --- 모델 선언 및 학습 ---
model = UNetSmall(upsample_mode='deconv', net_scaling=None, edge_crop=0)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.BCELoss()

# 간단히 30 epoch만
for epoch in range(30):
    model.train()
    total_loss = 0
    for xb, yb in loader:
        pred = model(xb)
        loss = criterion(pred, yb)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    print(f"Epoch {epoch+1}, Loss: {total_loss/len(loader):.4f}")
# Out:
# Epoch 1, Loss: 0.6932
# Epoch 2, Loss: 0.6931
# Epoch 3, Loss: 0.6931
# Epoch 4, Loss: 0.6931
# Epoch 5, Loss: 0.6930
# Epoch 6, Loss: 0.6930
# Epoch 7, Loss: 0.6929
# Epoch 8, Loss: 0.6928
# Epoch 9, Loss: 0.6926
# Epoch 10, Loss: 0.6924
# Epoch 11, Loss: 0.6922
# Epoch 12, Loss: 0.6920
# Epoch 13, Loss: 0.6918
# Epoch 14, Loss: 0.6915
# Epoch 15, Loss: 0.6913
# Epoch 16, Loss: 0.6910
# Epoch 17, Loss: 0.6907
# Epoch 18, Loss: 0.6905
# Epoch 19, Loss: 0.6902
# Epoch 20, Loss: 0.6900
# Epoch 21, Loss: 0.6897
# Epoch 22, Loss: 0.6894
# Epoch 23, Loss: 0.6890
# Epoch 24, Loss: 0.6887
# Epoch 25, Loss: 0.6882
# Epoch 26, Loss: 0.6877
# Epoch 27, Loss: 0.6872
# Epoch 28, Loss: 0.6867
# Epoch 29, Loss: 0.6863
# Epoch 30, Loss: 0.6857

# %% [markdown]
# ## **아래 주석을 풀고 U-Net 모델에 대해 간단히 설명해주세요 😀**

# %% [markdown]
# [답변]
#
#
# ---
#  U자 모양의 인공신경망 구조이며 이미지에서 특정 영역을 찾아내는 데 뛰어난 성능을 보인다. 인코더는 이미지를 점점 작고 깊게 만든다. 이미지를 계속 작은 크기로 줄이며 특징만 남겨 무엇이 중요한지 추려낸다. 디코더는 줄인 이미지를 다시 원래 크기로 복원한다. 이때 위치 정보를 함께 복원한다.
#  디코더는 인코더 정보를 skip connection으로 함게 사용하여, 인코더에서 추출한 정보를 디코더에서 활용할 수 있다.

# %% [markdown]
# ## **아래 주석을 풀고 DeepLabv1, v2, v3. v3+  모델에 대해 각각 간단히 설명해주세요 🐶**

# %% [markdown]
# [답변]
#
#
# ---
#
# [DeepLab v1]
#
# 기존 CNN은 다운샘플링으로 인해 해상도가 감소하여 객체의 경계 정보가 손실되는 문제가 있었다. 이를 해결하기 위해 Atrous Convolution을 도입하여 해상도를 유지라면서 receptive field를 확장했다. 백본 네트워크는 VGG-16이며 Atrous Convolution을 3개의 마지막 합성곱층에 적용하여 해상도를 유지한다. 그 후 CRF(Fully Connected Conditional Random Field)를 적용하여 경계를 보정한다.
#
# [DeepLab v2]
#
# 다양한 크기의 객체를 효과적으로 인식하기 어렵다는 문제를 해결하기 위해 Atrous Spatial Pyramid Pooling을 도입하여 다양한 수용 영역을 병렬로 적용하는 모델이다. 백본 네트워크는 ResNet-101이며 Atrous rate를 다르게 설정한 convolution을 병렬로 적용하여 멀티스케일 정보 수집을 하는 ASPP를 이용한다. 이후 DenseCRF를 사용하여 경계를 보정한다.
#
# [DeepLab v3]
#
# 객체의 다양한 크기와 복잡한 배경으로 인해 정확한 분할이 어려운 문제를 해결하기 위해 개선된 ASPP와 Global Average Pooling을 도입하여 더 넓은 문맥 정보를 수집하는 모델이다. 백본 네트워크는 ResNet-101 또는 Xception이다. 1x1 conv, 다양한 atrous rate의 3x3 conv, 이미지 수준의 피처를 포함하는 개선된 ASPP를 사용한다.
#
# [DeepLab v3+]
# 객체의 경계가 부정확하게 분할되는 문제를 해결하기 위해 Decoder를 추가하여 저수준 피처와 고수준 피처를 결합해 경계 복원 강화를 한 모델이다. 백본 네트워크는 DeepLab v3와 같다. 디코더는 저수준 피처와 고수준 피처를 결합하여 세부 정보를 복원한다. 그리고 계산 효율성을 높이기 위해 Depthwise Separable Convolution을 사용한다.
