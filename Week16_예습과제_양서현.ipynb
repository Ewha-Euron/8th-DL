# %% [markdown]
# #8.3.2 배치 정규화와 드롭아웃

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np

import torchvision
import torchvision.transforms as transforms

import torch.nn as nn
import torch.optim as optim

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
trainset = torchvision.datasets.FashionMNIST(root='/', train=True,
                                        download=True,
                                        transform=transforms.ToTensor())
# Out:
# 100%|██████████| 26.4M/26.4M [00:01<00:00, 18.9MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 306kB/s]
# 100%|██████████| 4.42M/4.42M [00:00<00:00, 5.52MB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 14.8MB/s]

# %%
batch_size = 4

# %%
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True)

# %%
dataiter = iter(trainloader)
images, labels = next(dataiter)

print(images.shape)
print(images[0].shape)
print(labels[0].item())
# Out:
# torch.Size([4, 1, 28, 28])
# torch.Size([1, 28, 28])
# 6

# %%
def imshow(img, title):
    plt.figure(figsize=(batch_size * 4, 4))
    plt.axis('off')
    plt.imshow(np.transpose(img, (1, 2, 0)))
    plt.title(title)
    plt.show()

# %%
def show_batch_images(dataloader):
    images, labels = next(iter(dataloader))

    img = torchvision.utils.make_grid(images)
    imshow(img, title=[str(x.item()) for x in labels])

    return images, labels

# %%
images, labels = show_batch_images(trainloader)

# %%
class NormalNet(nn.Module):
    def __init__(self):
        super(NormalNet, self).__init__()
        self.classifier = nn.Sequential(
            nn.Linear(784, 48),  # 28 x 28 = 784
            nn.ReLU(),
            nn.Linear(48, 24),
            nn.ReLU(),
            nn.Linear(24, 10)
        )

    def forward(self, x):
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x

# %%
class BNNet(nn.Module):
    def __init__(self):
        super(BNNet, self).__init__()
        self.classifier = nn.Sequential(
            nn.Linear(784, 48),
            nn.BatchNorm1d(48),
            nn.ReLU(),
            nn.Linear(48, 24),
            nn.BatchNorm1d(24),
            nn.ReLU(),
            nn.Linear(24, 10)
        )

    def forward(self, x):
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x

# %%
model = NormalNet().to(device)
print(model)
# Out:
# NormalNet(
#   (classifier): Sequential(
#     (0): Linear(in_features=784, out_features=48, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=48, out_features=24, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=24, out_features=10, bias=True)
#   )
# )

# %%
model_bn = BNNet().to(device)
print(model_bn)
# Out:
# BNNet(
#   (classifier): Sequential(
#     (0): Linear(in_features=784, out_features=48, bias=True)
#     (1): BatchNorm1d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=48, out_features=24, bias=True)
#     (4): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): Linear(in_features=24, out_features=10, bias=True)
#   )
# )

# %%
batch_size = 512

# %%
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True)

# %%
loss_fn = nn.CrossEntropyLoss().to(device)
opt = optim.SGD(model.parameters(), lr=0.01)
opt_bn = optim.SGD(model_bn.parameters(), lr=0.01)

# %%
loss_arr = []
loss_bn_arr = []
max_epochs = 20

for epoch in range(max_epochs):
    for i, data in enumerate(trainloader, 0):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        opt.zero_grad()
        outputs = model(inputs).to(device)
        loss = loss_fn(outputs, labels)
        loss.backward()
        opt.step()

        opt_bn.zero_grad()
        outputs_bn = model_bn(inputs)
        loss_bn = loss_fn(outputs_bn, labels)
        loss_bn.backward()
        opt_bn.step()

        loss_arr.append(loss.item())
        loss_bn_arr.append(loss_bn.item())

    plt.plot(loss_arr, 'yellow', label='Normal')
    plt.plot(loss_bn_arr, 'blue', label='BatchNorm')
    plt.legend()
    plt.show()

# %%
N = 50
noise = 0.3

x_train = torch.unsqueeze(torch.linspace(-1, 1, N), 1)
y_train = x_train + noise * torch.normal(torch.zeros(N, 1), torch.ones(N, 1))
#x_train, y_train= x_train.to(device), y_train.to(device)
x_test = torch.unsqueeze(torch.linspace(-1, 1, N), 1)
y_test = x_test + noise * torch.normal(torch.zeros(N, 1), torch.ones(N, 1))
#x_test, y_test = x_test.to(device), y_test.to(device)

# %%
plt.scatter(x_train.data.numpy(), y_train.data.numpy(), c='purple', alpha=0.5, label='train')
plt.scatter(x_test.data.numpy(), y_test.data.numpy(), c='yellow', alpha=0.5, label='test')
plt.legend()
plt.show()

# %%
N_h = 100
model = torch.nn.Sequential(
    torch.nn.Linear(1, N_h),
    torch.nn.ReLU(),
    torch.nn.Linear(N_h, N_h),
    torch.nn.ReLU(),
    torch.nn.Linear(N_h, 1),
)

model_dropout = torch.nn.Sequential(
    torch.nn.Linear(1, N_h),
    torch.nn.Dropout(0.2),
    torch.nn.ReLU(),
    torch.nn.Linear(N_h, N_h),
    torch.nn.Dropout(0.2),
    torch.nn.ReLU(),
    torch.nn.Linear(N_h, 1),
)

# %%
opt = torch.optim.Adam(model.parameters(), lr=0.01)
opt_dropout = torch.optim.Adam(model_dropout.parameters(), lr=0.01)
loss_fn = torch.nn.MSELoss().to(device)

# %%
max_epochs = 1000
for epoch in range(max_epochs):
    pred = model(x_train)
    loss = loss_fn(pred, y_train)
    opt.zero_grad()
    loss.backward()
    opt.step()

    pred_dropout = model_dropout(x_train)
    loss_dropout = loss_fn(pred_dropout, y_train)
    opt_dropout.zero_grad()
    loss_dropout.backward()
    opt_dropout.step()

    if epoch % 50 == 0:
        model.eval()
        model_dropout.eval()

        test_pred = model(x_test)
        test_loss = loss_fn(test_pred, y_test)

        test_pred_dropout = model_dropout(x_test)
        test_loss_dropout = loss_fn(test_pred_dropout, y_test)

        plt.scatter(x_train.data.numpy(), y_train.data.numpy(), c='purple', alpha=0.5, label='train')
        plt.scatter(x_test.data.numpy(), y_test.data.numpy(), c='yellow', alpha=0.5, label='test')
        plt.plot(x_test.data.numpy(), test_pred.data.numpy(), 'b-', lw=3, label='normal')
        plt.plot(x_test.data.numpy(), test_pred_dropout.data.numpy(), 'g--', lw=3,  label='dropout')

        plt.title('Epoch %d, Loss = %0.4f, Loss with dropout = %0.4f' % (epoch, test_loss, test_loss_dropout))
        plt.legend()
        model.train()
        model_dropout.train()
        plt.pause(0.05)

# %% [markdown]
# ---
#
# #8.3.3 조기 종료

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models
from torchvision import transforms, datasets

import matplotlib
import matplotlib.pyplot as plt
import time
import argparse
from tqdm import tqdm
matplotlib.style.use('ggplot')

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
train_transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.RandomHorizontalFlip(),
        transforms.RandomVerticalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225])
    ])
val_transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225])
    ])

# %%
# prompt: /content/archive.zip의 zip을 풀고 archive 폴더로 저장해줘

# !unzip /content/archive.zip -d /content/archive
# Out:
# Archive:  /content/archive.zip
#    creating: /content/archive/test/
#    creating: /content/archive/test/hot_dog/
#   inflating: /content/archive/test/hot_dog/133012.jpg
#   inflating: /content/archive/test/hot_dog/133015.jpg
#   inflating: /content/archive/test/hot_dog/133245.jpg
#   inflating: /content/archive/test/hot_dog/135628.jpg
#   inflating: /content/archive/test/hot_dog/138933.jpg
#   inflating: /content/archive/test/hot_dog/138937.jpg
#   inflating: /content/archive/test/hot_dog/138969.jpg
#   inflating: /content/archive/test/hot_dog/139177.jpg
#   inflating: /content/archive/test/hot_dog/142835.jpg
#   inflating: /content/archive/test/hot_dog/143012.jpg
#   inflating: /content/archive/test/hot_dog/144956.jpg
#   inflating: /content/archive/test/hot_dog/146227.jpg
#   inflating: /content/archive/test/hot_dog/146834.jpg
#   inflating: /content/archive/test/hot_dog/147874.jpg
#   inflating: /content/archive/test/hot_dog/152106.jpg
#   inflating: /content/archive/test/hot_dog/154409.jpg
#   inflating: /content/archive/test/hot_dog/154545.jpg
#   inflating: /content/archive/test/hot_dog/156126.jpg
#   inflating: /content/archive/test/hot_dog/156135.jpg
#   inflating: /content/archive/test/hot_dog/160274.jpg
#   inflating: /content/archive/test/hot_dog/160523.jpg
#   inflating: /content/archive/test/hot_dog/161911.jpg
#   inflating: /content/archive/test/hot_dog/165005.jpg
#   inflating: /content/archive/test/hot_dog/170212.jpg
#   inflating: /content/archive/test/hot_dog/170452.jpg
#   inflating: /content/archive/test/hot_dog/171607.jpg
#   inflating: /content/archive/test/hot_dog/171875.jpg
#   inflating: /content/archive/test/hot_dog/173995.jpg
#   inflating: /content/archive/test/hot_dog/180961.jpg
#   inflating: /content/archive/test/hot_dog/183400.jpg
#   inflating: /content/archive/test/hot_dog/189511.jpg
#   inflating: /content/archive/test/hot_dog/190809.jpg
#   inflating: /content/archive/test/hot_dog/193755.jpg
#   inflating: /content/archive/test/hot_dog/195251.jpg
#   inflating: /content/archive/test/hot_dog/197257.jpg
#   inflating: /content/archive/test/hot_dog/198641.jpg
#   inflating: /content/archive/test/hot_dog/200438.jpg
#   inflating: /content/archive/test/hot_dog/201986.jpg
#   inflating: /content/archive/test/hot_dog/206995.jpg
#   inflating: /content/archive/test/hot_dog/207291.jpg
#   inflating: /content/archive/test/hot_dog/207335.jpg
#   inflating: /content/archive/test/hot_dog/209306.jpg
#   inflating: /content/archive/test/hot_dog/210271.jpg
#   inflating: /content/archive/test/hot_dog/210861.jpg
#   inflating: /content/archive/test/hot_dog/211824.jpg
#   inflating: /content/archive/test/hot_dog/212515.jpg
#   inflating: /content/archive/test/hot_dog/219273.jpg
#   inflating: /content/archive/test/hot_dog/219922.jpg
#   inflating: /content/archive/test/hot_dog/224850.jpg
#   inflating: /content/archive/test/hot_dog/225367.jpg
#   inflating: /content/archive/test/hot_dog/233179.jpg
#   inflating: /content/archive/test/hot_dog/238581.jpg
#   inflating: /content/archive/test/hot_dog/248122.jpg
#   inflating: /content/archive/test/hot_dog/250715.jpg
#   inflating: /content/archive/test/hot_dog/259058.jpg
#   inflating: /content/archive/test/hot_dog/259418.jpg
#   inflating: /content/archive/test/hot_dog/264487.jpg
#   inflating: /content/archive/test/hot_dog/267629.jpg
#   inflating: /content/archive/test/hot_dog/267988.jpg
#   inflating: /content/archive/test/hot_dog/268919.jpg
#   inflating: /content/archive/test/hot_dog/282294.jpg
#   inflating: /content/archive/test/hot_dog/285214.jpg
#   inflating: /content/archive/test/hot_dog/287752.jpg
#   inflating: /content/archive/test/hot_dog/289042.jpg
#   inflating: /content/archive/test/hot_dog/289472.jpg
#   inflating: /content/archive/test/hot_dog/291354.jpg
#   inflating: /content/archive/test/hot_dog/292683.jpg
#   inflating: /content/archive/test/hot_dog/295307.jpg
#   inflating: /content/archive/test/hot_dog/298744.jpg
#   inflating: /content/archive/test/hot_dog/298757.jpg
#   inflating: /content/archive/test/hot_dog/300150.jpg
#   inflating: /content/archive/test/hot_dog/302949.jpg
#   inflating: /content/archive/test/hot_dog/306950.jpg
#   inflating: /content/archive/test/hot_dog/307557.jpg
#   inflating: /content/archive/test/hot_dog/307874.jpg
#   inflating: /content/archive/test/hot_dog/315220.jpg
#   inflating: /content/archive/test/hot_dog/315602.jpg
#   inflating: /content/archive/test/hot_dog/315747.jpg
#   inflating: /content/archive/test/hot_dog/316636.jpg
#   inflating: /content/archive/test/hot_dog/317564.jpg
#   inflating: /content/archive/test/hot_dog/319114.jpg
#   inflating: /content/archive/test/hot_dog/324480.jpg
#   inflating: /content/archive/test/hot_dog/324507.jpg
#   inflating: /content/archive/test/hot_dog/327851.jpg
#   inflating: /content/archive/test/hot_dog/332886.jpg
#   inflating: /content/archive/test/hot_dog/335113.jpg
#   inflating: /content/archive/test/hot_dog/336873.jpg
#   inflating: /content/archive/test/hot_dog/337987.jpg
#   inflating: /content/archive/test/hot_dog/343270.jpg
#   inflating: /content/archive/test/hot_dog/345704.jpg
#   inflating: /content/archive/test/hot_dog/349375.jpg
#   inflating: /content/archive/test/hot_dog/352638.jpg
#   inflating: /content/archive/test/hot_dog/365524.jpg
#   inflating: /content/archive/test/hot_dog/370167.jpg
#   inflating: /content/archive/test/hot_dog/371082.jpg
#   inflating: /content/archive/test/hot_dog/373020.jpg
#   inflating: /content/archive/test/hot_dog/373912.jpg
#   inflating: /content/archive/test/hot_dog/377852.jpg
#   inflating: /content/archive/test/hot_dog/379311.jpg
#   inflating: /content/archive/test/hot_dog/380645.jpg
#   inflating: /content/archive/test/hot_dog/380963.jpg
#   inflating: /content/archive/test/hot_dog/382188.jpg
#   inflating: /content/archive/test/hot_dog/388733.jpg
#   inflating: /content/archive/test/hot_dog/388827.jpg
#   inflating: /content/archive/test/hot_dog/391898.jpg
#   inflating: /content/archive/test/hot_dog/393123.jpg
#   inflating: /content/archive/test/hot_dog/397071.jpg
#   inflating: /content/archive/test/hot_dog/397466.jpg
#   inflating: /content/archive/test/hot_dog/397696.jpg
#   inflating: /content/archive/test/hot_dog/398941.jpg
#   inflating: /content/archive/test/hot_dog/400228.jpg
#   inflating: /content/archive/test/hot_dog/403561.jpg
#   inflating: /content/archive/test/hot_dog/408504.jpg
#   inflating: /content/archive/test/hot_dog/409435.jpg
#   inflating: /content/archive/test/hot_dog/410713.jpg
#   inflating: /content/archive/test/hot_dog/413426.jpg
#   inflating: /content/archive/test/hot_dog/413825.jpg
#   inflating: /content/archive/test/hot_dog/415744.jpg
#   inflating: /content/archive/test/hot_dog/417155.jpg
#   inflating: /content/archive/test/hot_dog/419255.jpg
#   inflating: /content/archive/test/hot_dog/422730.jpg
#   inflating: /content/archive/test/hot_dog/423659.jpg
#   inflating: /content/archive/test/hot_dog/424960.jpg
#   inflating: /content/archive/test/hot_dog/439441.jpg
#   inflating: /content/archive/test/hot_dog/445366.jpg
#   inflating: /content/archive/test/hot_dog/453463.jpg
#   inflating: /content/archive/test/hot_dog/456751.jpg
#   inflating: /content/archive/test/hot_dog/458164.jpg
#   inflating: /content/archive/test/hot_dog/461937.jpg
#   inflating: /content/archive/test/hot_dog/462004.jpg
#   inflating: /content/archive/test/hot_dog/471340.jpg
#   inflating: /content/archive/test/hot_dog/480916.jpg
#   inflating: /content/archive/test/hot_dog/485835.jpg
#   inflating: /content/archive/test/hot_dog/486658.jpg
#   inflating: /content/archive/test/hot_dog/489624.jpg
#   inflating: /content/archive/test/hot_dog/493727.jpg
#   inflating: /content/archive/test/hot_dog/498141.jpg
#   inflating: /content/archive/test/hot_dog/500768.jpg
#   inflating: /content/archive/test/hot_dog/500771.jpg
#   inflating: /content/archive/test/hot_dog/502977.jpg
#   inflating: /content/archive/test/hot_dog/505563.jpg
#   inflating: /content/archive/test/hot_dog/505584.jpg
#   inflating: /content/archive/test/hot_dog/510674.jpg
#   inflating: /content/archive/test/hot_dog/510955.jpg
#   inflating: /content/archive/test/hot_dog/514482.jpg
#   inflating: /content/archive/test/hot_dog/518867.jpg
#   inflating: /content/archive/test/hot_dog/520065.jpg
#   inflating: /content/archive/test/hot_dog/520905.jpg
#   inflating: /content/archive/test/hot_dog/527074.jpg
#   inflating: /content/archive/test/hot_dog/527633.jpg
#   inflating: /content/archive/test/hot_dog/528022.jpg
#   inflating: /content/archive/test/hot_dog/530316.jpg
#   inflating: /content/archive/test/hot_dog/531567.jpg
#   inflating: /content/archive/test/hot_dog/533172.jpg
#   inflating: /content/archive/test/hot_dog/533521.jpg
#   inflating: /content/archive/test/hot_dog/537584.jpg
#   inflating: /content/archive/test/hot_dog/544416.jpg
#   inflating: /content/archive/test/hot_dog/547307.jpg
#   inflating: /content/archive/test/hot_dog/547312.jpg
#   inflating: /content/archive/test/hot_dog/550512.jpg
#   inflating: /content/archive/test/hot_dog/551784.jpg
#   inflating: /content/archive/test/hot_dog/554307.jpg
#   inflating: /content/archive/test/hot_dog/558890.jpg
#   inflating: /content/archive/test/hot_dog/561681.jpg
#   inflating: /content/archive/test/hot_dog/564558.jpg
#   inflating: /content/archive/test/hot_dog/566784.jpg
#   inflating: /content/archive/test/hot_dog/566965.jpg
#   inflating: /content/archive/test/hot_dog/570799.jpg
#   inflating: /content/archive/test/hot_dog/571081.jpg
#   inflating: /content/archive/test/hot_dog/573731.jpg
#   inflating: /content/archive/test/hot_dog/574379.jpg
#   inflating: /content/archive/test/hot_dog/576265.jpg
#   inflating: /content/archive/test/hot_dog/580378.jpg
#   inflating: /content/archive/test/hot_dog/581166.jpg
#   inflating: /content/archive/test/hot_dog/583811.jpg
#   inflating: /content/archive/test/hot_dog/588881.jpg
#   inflating: /content/archive/test/hot_dog/591179.jpg
#   inflating: /content/archive/test/hot_dog/593867.jpg
#   inflating: /content/archive/test/hot_dog/595636.jpg
#   inflating: /content/archive/test/hot_dog/595968.jpg
#   inflating: /content/archive/test/hot_dog/599728.jpg
#   inflating: /content/archive/test/hot_dog/602204.jpg
#   inflating: /content/archive/test/hot_dog/604245.jpg
#   inflating: /content/archive/test/hot_dog/607287.jpg
#   inflating: /content/archive/test/hot_dog/607289.jpg
#   inflating: /content/archive/test/hot_dog/608168.jpg
#   inflating: /content/archive/test/hot_dog/612440.jpg
#   inflating: /content/archive/test/hot_dog/618167.jpg
#   inflating: /content/archive/test/hot_dog/619671.jpg
#   inflating: /content/archive/test/hot_dog/623958.jpg
#   inflating: /content/archive/test/hot_dog/628106.jpg
#   inflating: /content/archive/test/hot_dog/632174.jpg
#   inflating: /content/archive/test/hot_dog/634232.jpg
#   inflating: /content/archive/test/hot_dog/635712.jpg
#   inflating: /content/archive/test/hot_dog/635715.jpg
#   inflating: /content/archive/test/hot_dog/640478.jpg
#   inflating: /content/archive/test/hot_dog/642331.jpg
#   inflating: /content/archive/test/hot_dog/646412.jpg
#   inflating: /content/archive/test/hot_dog/650514.jpg
#   inflating: /content/archive/test/hot_dog/651101.jpg
#   inflating: /content/archive/test/hot_dog/652826.jpg
#   inflating: /content/archive/test/hot_dog/654831.jpg
#   inflating: /content/archive/test/hot_dog/665987.jpg
#   inflating: /content/archive/test/hot_dog/667655.jpg
#   inflating: /content/archive/test/hot_dog/677481.jpg
#   inflating: /content/archive/test/hot_dog/679424.jpg
#   inflating: /content/archive/test/hot_dog/690320.jpg
#   inflating: /content/archive/test/hot_dog/690327.jpg
#   inflating: /content/archive/test/hot_dog/691952.jpg
#   inflating: /content/archive/test/hot_dog/697073.jpg
#   inflating: /content/archive/test/hot_dog/697329.jpg
#   inflating: /content/archive/test/hot_dog/701201.jpg
#   inflating: /content/archive/test/hot_dog/701763.jpg
#   inflating: /content/archive/test/hot_dog/703550.jpg
#   inflating: /content/archive/test/hot_dog/704107.jpg
#   inflating: /content/archive/test/hot_dog/704826.jpg
#   inflating: /content/archive/test/hot_dog/707784.jpg
#   inflating: /content/archive/test/hot_dog/716049.jpg
#   inflating: /content/archive/test/hot_dog/717652.jpg
#   inflating: /content/archive/test/hot_dog/718939.jpg
#   inflating: /content/archive/test/hot_dog/723890.jpg
#   inflating: /content/archive/test/hot_dog/724711.jpg
#   inflating: /content/archive/test/hot_dog/728442.jpg
#   inflating: /content/archive/test/hot_dog/731744.jpg
#   inflating: /content/archive/test/hot_dog/739229.jpg
#   inflating: /content/archive/test/hot_dog/741637.jpg
#   inflating: /content/archive/test/hot_dog/741652.jpg
#   inflating: /content/archive/test/hot_dog/745739.jpg
#   inflating: /content/archive/test/hot_dog/745741.jpg
#   inflating: /content/archive/test/hot_dog/752871.jpg
#   inflating: /content/archive/test/hot_dog/756061.jpg
#   inflating: /content/archive/test/hot_dog/760045.jpg
#   inflating: /content/archive/test/hot_dog/762910.jpg
#   inflating: /content/archive/test/hot_dog/784362.jpg
#   inflating: /content/archive/test/hot_dog/800992.jpg
#   inflating: /content/archive/test/hot_dog/803307.jpg
#   inflating: /content/archive/test/hot_dog/805852.jpg
#   inflating: /content/archive/test/hot_dog/807265.jpg
#   inflating: /content/archive/test/hot_dog/807481.jpg
#   inflating: /content/archive/test/hot_dog/815805.jpg
#   inflating: /content/archive/test/hot_dog/818233.jpg
#   inflating: /content/archive/test/hot_dog/824342.jpg
#   inflating: /content/archive/test/hot_dog/826706.jpg
#   inflating: /content/archive/test/hot_dog/829968.jpg
#   inflating: /content/archive/test/hot_dog/838604.jpg
#   inflating: /content/archive/test/hot_dog/839783.jpg
#   inflating: /content/archive/test/hot_dog/840832.jpg
#   inflating: /content/archive/test/hot_dog/840839.jpg
#   inflating: /content/archive/test/hot_dog/841980.jpg
#   inflating: /content/archive/test/hot_dog/842474.jpg
#    creating: /content/archive/test/not_hot_dog/
#   inflating: /content/archive/test/not_hot_dog/13023.jpg
#   inflating: /content/archive/test/not_hot_dog/13080.jpg
#   inflating: /content/archive/test/not_hot_dog/13719.jpg
#   inflating: /content/archive/test/not_hot_dog/13983.jpg
#   inflating: /content/archive/test/not_hot_dog/14142.jpg
#   inflating: /content/archive/test/not_hot_dog/14484.jpg
#   inflating: /content/archive/test/not_hot_dog/15420.jpg
#   inflating: /content/archive/test/not_hot_dog/15580.jpg
#   inflating: /content/archive/test/not_hot_dog/15787.jpg
#   inflating: /content/archive/test/not_hot_dog/15933.jpg
#   inflating: /content/archive/test/not_hot_dog/17304.jpg
#   inflating: /content/archive/test/not_hot_dog/17394.jpg
#   inflating: /content/archive/test/not_hot_dog/17688.jpg
#   inflating: /content/archive/test/not_hot_dog/17969.jpg
#   inflating: /content/archive/test/not_hot_dog/18985.jpg
#   inflating: /content/archive/test/not_hot_dog/19143.jpg
#   inflating: /content/archive/test/not_hot_dog/19487.jpg
#   inflating: /content/archive/test/not_hot_dog/20087.jpg
#   inflating: /content/archive/test/not_hot_dog/20215.jpg
#   inflating: /content/archive/test/not_hot_dog/20532.jpg
#   inflating: /content/archive/test/not_hot_dog/20627.jpg
#   inflating: /content/archive/test/not_hot_dog/20777.jpg
#   inflating: /content/archive/test/not_hot_dog/20787.jpg
#   inflating: /content/archive/test/not_hot_dog/20797.jpg
#   inflating: /content/archive/test/not_hot_dog/20983.jpg
#   inflating: /content/archive/test/not_hot_dog/21327.jpg
#   inflating: /content/archive/test/not_hot_dog/21440.jpg
#   inflating: /content/archive/test/not_hot_dog/22080.jpg
#   inflating: /content/archive/test/not_hot_dog/22489.jpg
#   inflating: /content/archive/test/not_hot_dog/22777.jpg
#   inflating: /content/archive/test/not_hot_dog/23184.jpg
#   inflating: /content/archive/test/not_hot_dog/23199.jpg
#   inflating: /content/archive/test/not_hot_dog/23601.jpg
#   inflating: /content/archive/test/not_hot_dog/23739.jpg
#   inflating: /content/archive/test/not_hot_dog/24145.jpg
#   inflating: /content/archive/test/not_hot_dog/24159.jpg
#   inflating: /content/archive/test/not_hot_dog/24479.jpg
#   inflating: /content/archive/test/not_hot_dog/24656.jpg
#   inflating: /content/archive/test/not_hot_dog/24844.jpg
#   inflating: /content/archive/test/not_hot_dog/25026.jpg
#   inflating: /content/archive/test/not_hot_dog/25414.jpg
#   inflating: /content/archive/test/not_hot_dog/25784.jpg
#   inflating: /content/archive/test/not_hot_dog/26078.jpg
#   inflating: /content/archive/test/not_hot_dog/26279.jpg
#   inflating: /content/archive/test/not_hot_dog/26489.jpg
#   inflating: /content/archive/test/not_hot_dog/27330.jpg
#   inflating: /content/archive/test/not_hot_dog/27410.jpg
#   inflating: /content/archive/test/not_hot_dog/27415.jpg
#   inflating: /content/archive/test/not_hot_dog/27963.jpg
#   inflating: /content/archive/test/not_hot_dog/28387.jpg
#   inflating: /content/archive/test/not_hot_dog/28783.jpg
#   inflating: /content/archive/test/not_hot_dog/28996.jpg
#   inflating: /content/archive/test/not_hot_dog/29204.jpg
#   inflating: /content/archive/test/not_hot_dog/29417.jpg
#   inflating: /content/archive/test/not_hot_dog/29869.jpg
#   inflating: /content/archive/test/not_hot_dog/30395.jpg
#   inflating: /content/archive/test/not_hot_dog/30731.jpg
#   inflating: /content/archive/test/not_hot_dog/30892.jpg
#   inflating: /content/archive/test/not_hot_dog/31881.jpg
#   inflating: /content/archive/test/not_hot_dog/32004.jpg
#   inflating: /content/archive/test/not_hot_dog/32199.jpg
#   inflating: /content/archive/test/not_hot_dog/32556.jpg
#   inflating: /content/archive/test/not_hot_dog/32666.jpg
#   inflating: /content/archive/test/not_hot_dog/32693.jpg
#   inflating: /content/archive/test/not_hot_dog/33259.jpg
#   inflating: /content/archive/test/not_hot_dog/33485.jpg
#   inflating: /content/archive/test/not_hot_dog/33783.jpg
#   inflating: /content/archive/test/not_hot_dog/34632.jpg
#   inflating: /content/archive/test/not_hot_dog/34793.jpg
#   inflating: /content/archive/test/not_hot_dog/35133.jpg
#   inflating: /content/archive/test/not_hot_dog/35235.jpg
#   inflating: /content/archive/test/not_hot_dog/35430.jpg
#   inflating: /content/archive/test/not_hot_dog/36042.jpg
#   inflating: /content/archive/test/not_hot_dog/36081.jpg
#   inflating: /content/archive/test/not_hot_dog/36147.jpg
#   inflating: /content/archive/test/not_hot_dog/36370.jpg
#   inflating: /content/archive/test/not_hot_dog/37384.jpg
#   inflating: /content/archive/test/not_hot_dog/37565.jpg
#   inflating: /content/archive/test/not_hot_dog/37649.jpg
#   inflating: /content/archive/test/not_hot_dog/38337.jpg
#   inflating: /content/archive/test/not_hot_dog/38349.jpg
#   inflating: /content/archive/test/not_hot_dog/38442.jpg
#   inflating: /content/archive/test/not_hot_dog/38615.jpg
#   inflating: /content/archive/test/not_hot_dog/38768.jpg
#   inflating: /content/archive/test/not_hot_dog/39461.jpg
#   inflating: /content/archive/test/not_hot_dog/40094.jpg
#   inflating: /content/archive/test/not_hot_dog/40231.jpg
#   inflating: /content/archive/test/not_hot_dog/40449.jpg
#   inflating: /content/archive/test/not_hot_dog/40762.jpg
#   inflating: /content/archive/test/not_hot_dog/40944.jpg
#   inflating: /content/archive/test/not_hot_dog/40947.jpg
#   inflating: /content/archive/test/not_hot_dog/41693.jpg
#   inflating: /content/archive/test/not_hot_dog/42125.jpg
#   inflating: /content/archive/test/not_hot_dog/42252.jpg
#   inflating: /content/archive/test/not_hot_dog/42487.jpg
#   inflating: /content/archive/test/not_hot_dog/42609.jpg
#   inflating: /content/archive/test/not_hot_dog/42954.jpg
#   inflating: /content/archive/test/not_hot_dog/43376.jpg
#   inflating: /content/archive/test/not_hot_dog/43636.jpg
#   inflating: /content/archive/test/not_hot_dog/43886.jpg
#   inflating: /content/archive/test/not_hot_dog/43924.jpg
#   inflating: /content/archive/test/not_hot_dog/44035.jpg
#   inflating: /content/archive/test/not_hot_dog/44449.jpg
#   inflating: /content/archive/test/not_hot_dog/44578.jpg
#   inflating: /content/archive/test/not_hot_dog/44810.jpg
#   inflating: /content/archive/test/not_hot_dog/44859.jpg
#   inflating: /content/archive/test/not_hot_dog/45035.jpg
#   inflating: /content/archive/test/not_hot_dog/45059.jpg
#   inflating: /content/archive/test/not_hot_dog/45200.jpg
#   inflating: /content/archive/test/not_hot_dog/45817.jpg
#   inflating: /content/archive/test/not_hot_dog/45896.jpg
#   inflating: /content/archive/test/not_hot_dog/46246.jpg
#   inflating: /content/archive/test/not_hot_dog/46325.jpg
#   inflating: /content/archive/test/not_hot_dog/46401.jpg
#   inflating: /content/archive/test/not_hot_dog/47115.jpg
#   inflating: /content/archive/test/not_hot_dog/47388.jpg
#   inflating: /content/archive/test/not_hot_dog/47909.jpg
#   inflating: /content/archive/test/not_hot_dog/48052.jpg
#   inflating: /content/archive/test/not_hot_dog/48073.jpg
#   inflating: /content/archive/test/not_hot_dog/48151.jpg
#   inflating: /content/archive/test/not_hot_dog/48208.jpg
#   inflating: /content/archive/test/not_hot_dog/48506.jpg
#   inflating: /content/archive/test/not_hot_dog/48840.jpg
#   inflating: /content/archive/test/not_hot_dog/49803.jpg
#   inflating: /content/archive/test/not_hot_dog/50193.jpg
#   inflating: /content/archive/test/not_hot_dog/50277.jpg
#   inflating: /content/archive/test/not_hot_dog/51368.jpg
#   inflating: /content/archive/test/not_hot_dog/51481.jpg
#   inflating: /content/archive/test/not_hot_dog/51533.jpg
#   inflating: /content/archive/test/not_hot_dog/51678.jpg
#   inflating: /content/archive/test/not_hot_dog/52510.jpg
#   inflating: /content/archive/test/not_hot_dog/52934.jpg
#   inflating: /content/archive/test/not_hot_dog/53217.jpg
#   inflating: /content/archive/test/not_hot_dog/53233.jpg
#   inflating: /content/archive/test/not_hot_dog/53393.jpg
#   inflating: /content/archive/test/not_hot_dog/53758.jpg
#   inflating: /content/archive/test/not_hot_dog/54252.jpg
#   inflating: /content/archive/test/not_hot_dog/54461.jpg
#   inflating: /content/archive/test/not_hot_dog/54529.jpg
#   inflating: /content/archive/test/not_hot_dog/54540.jpg
#   inflating: /content/archive/test/not_hot_dog/54685.jpg
#   inflating: /content/archive/test/not_hot_dog/55601.jpg
#   inflating: /content/archive/test/not_hot_dog/55639.jpg
#   inflating: /content/archive/test/not_hot_dog/56240.jpg
#   inflating: /content/archive/test/not_hot_dog/56337.jpg
#   inflating: /content/archive/test/not_hot_dog/56409.jpg
#   inflating: /content/archive/test/not_hot_dog/56449.jpg
#   inflating: /content/archive/test/not_hot_dog/57594.jpg
#   inflating: /content/archive/test/not_hot_dog/58448.jpg
#   inflating: /content/archive/test/not_hot_dog/58787.jpg
#   inflating: /content/archive/test/not_hot_dog/58856.jpg
#   inflating: /content/archive/test/not_hot_dog/59144.jpg
#   inflating: /content/archive/test/not_hot_dog/59445.jpg
#   inflating: /content/archive/test/not_hot_dog/59497.jpg
#   inflating: /content/archive/test/not_hot_dog/59675.jpg
#   inflating: /content/archive/test/not_hot_dog/60069.jpg
#   inflating: /content/archive/test/not_hot_dog/60207.jpg
#   inflating: /content/archive/test/not_hot_dog/60306.jpg
#   inflating: /content/archive/test/not_hot_dog/60633.jpg
#   inflating: /content/archive/test/not_hot_dog/60655.jpg
#   inflating: /content/archive/test/not_hot_dog/60819.jpg
#   inflating: /content/archive/test/not_hot_dog/60844.jpg
#   inflating: /content/archive/test/not_hot_dog/61656.jpg
#   inflating: /content/archive/test/not_hot_dog/61822.jpg
#   inflating: /content/archive/test/not_hot_dog/62084.jpg
#   inflating: /content/archive/test/not_hot_dog/6229.jpg
#   inflating: /content/archive/test/not_hot_dog/62484.jpg
#   inflating: /content/archive/test/not_hot_dog/6261.jpg
#   inflating: /content/archive/test/not_hot_dog/62622.jpg
#   inflating: /content/archive/test/not_hot_dog/62663.jpg
#   inflating: /content/archive/test/not_hot_dog/63099.jpg
#   inflating: /content/archive/test/not_hot_dog/63480.jpg
#   inflating: /content/archive/test/not_hot_dog/63878.jpg
#   inflating: /content/archive/test/not_hot_dog/63947.jpg
#   inflating: /content/archive/test/not_hot_dog/64906.jpg
#   inflating: /content/archive/test/not_hot_dog/64960.jpg
#   inflating: /content/archive/test/not_hot_dog/65097.jpg
#   inflating: /content/archive/test/not_hot_dog/65128.jpg
#   inflating: /content/archive/test/not_hot_dog/65608.jpg
#   inflating: /content/archive/test/not_hot_dog/65685.jpg
#   inflating: /content/archive/test/not_hot_dog/66183.jpg
#   inflating: /content/archive/test/not_hot_dog/66207.jpg
#   inflating: /content/archive/test/not_hot_dog/66533.jpg
#   inflating: /content/archive/test/not_hot_dog/66858.jpg
#   inflating: /content/archive/test/not_hot_dog/6709.jpg
#   inflating: /content/archive/test/not_hot_dog/68684.jpg
#   inflating: /content/archive/test/not_hot_dog/6926.jpg
#   inflating: /content/archive/test/not_hot_dog/69328.jpg
#   inflating: /content/archive/test/not_hot_dog/69414.jpg
#   inflating: /content/archive/test/not_hot_dog/69564.jpg
#   inflating: /content/archive/test/not_hot_dog/69645.jpg
#   inflating: /content/archive/test/not_hot_dog/70218.jpg
#   inflating: /content/archive/test/not_hot_dog/70456.jpg
#   inflating: /content/archive/test/not_hot_dog/7056.jpg
#   inflating: /content/archive/test/not_hot_dog/71511.jpg
#   inflating: /content/archive/test/not_hot_dog/71701.jpg
#   inflating: /content/archive/test/not_hot_dog/71719.jpg
#   inflating: /content/archive/test/not_hot_dog/72090.jpg
#   inflating: /content/archive/test/not_hot_dog/72716.jpg
#   inflating: /content/archive/test/not_hot_dog/73697.jpg
#   inflating: /content/archive/test/not_hot_dog/7394.jpg
#   inflating: /content/archive/test/not_hot_dog/75537.jpg
#   inflating: /content/archive/test/not_hot_dog/75638.jpg
#   inflating: /content/archive/test/not_hot_dog/76021.jpg
#   inflating: /content/archive/test/not_hot_dog/76061.jpg
#   inflating: /content/archive/test/not_hot_dog/76271.jpg
#   inflating: /content/archive/test/not_hot_dog/76464.jpg
#   inflating: /content/archive/test/not_hot_dog/76466.jpg
#   inflating: /content/archive/test/not_hot_dog/77677.jpg
#   inflating: /content/archive/test/not_hot_dog/78171.jpg
#   inflating: /content/archive/test/not_hot_dog/7847.jpg
#   inflating: /content/archive/test/not_hot_dog/79489.jpg
#   inflating: /content/archive/test/not_hot_dog/80190.jpg
#   inflating: /content/archive/test/not_hot_dog/80215.jpg
#   inflating: /content/archive/test/not_hot_dog/80315.jpg
#   inflating: /content/archive/test/not_hot_dog/80750.jpg
#   inflating: /content/archive/test/not_hot_dog/80865.jpg
#   inflating: /content/archive/test/not_hot_dog/80887.jpg
#   inflating: /content/archive/test/not_hot_dog/8119.jpg
#   inflating: /content/archive/test/not_hot_dog/81332.jpg
#   inflating: /content/archive/test/not_hot_dog/81543.jpg
#   inflating: /content/archive/test/not_hot_dog/81779.jpg
#   inflating: /content/archive/test/not_hot_dog/81939.jpg
#   inflating: /content/archive/test/not_hot_dog/82274.jpg
#   inflating: /content/archive/test/not_hot_dog/82535.jpg
#   inflating: /content/archive/test/not_hot_dog/82578.jpg
#   inflating: /content/archive/test/not_hot_dog/82772.jpg
#   inflating: /content/archive/test/not_hot_dog/82946.jpg
#   inflating: /content/archive/test/not_hot_dog/83053.jpg
#   inflating: /content/archive/test/not_hot_dog/8350.jpg
#   inflating: /content/archive/test/not_hot_dog/83538.jpg
#   inflating: /content/archive/test/not_hot_dog/85375.jpg
#   inflating: /content/archive/test/not_hot_dog/85398.jpg
#   inflating: /content/archive/test/not_hot_dog/85452.jpg
#   inflating: /content/archive/test/not_hot_dog/85514.jpg
#   inflating: /content/archive/test/not_hot_dog/86180.jpg
#   inflating: /content/archive/test/not_hot_dog/86528.jpg
#   inflating: /content/archive/test/not_hot_dog/86782.jpg
#   inflating: /content/archive/test/not_hot_dog/86812.jpg
#   inflating: /content/archive/test/not_hot_dog/87020.jpg
#   inflating: /content/archive/test/not_hot_dog/87125.jpg
#   inflating: /content/archive/test/not_hot_dog/87246.jpg
#   inflating: /content/archive/test/not_hot_dog/88158.jpg
#   inflating: /content/archive/test/not_hot_dog/89027.jpg
#   inflating: /content/archive/test/not_hot_dog/8917.jpg
#   inflating: /content/archive/test/not_hot_dog/8984.jpg
#   inflating: /content/archive/test/not_hot_dog/9053.jpg
#   inflating: /content/archive/test/not_hot_dog/9547.jpg
#   inflating: /content/archive/test/not_hot_dog/9555.jpg
#   inflating: /content/archive/test/not_hot_dog/9657.jpg
#    creating: /content/archive/train/
#    creating: /content/archive/train/hot_dog/
#   inflating: /content/archive/train/hot_dog/1000288.jpg
#   inflating: /content/archive/train/hot_dog/1011661.jpg
#   inflating: /content/archive/train/hot_dog/1013916.jpg
#   inflating: /content/archive/train/hot_dog/1017226.jpg
#   inflating: /content/archive/train/hot_dog/1018245.jpg
#   inflating: /content/archive/train/hot_dog/1023510.jpg
#   inflating: /content/archive/train/hot_dog/1040579.jpg
#   inflating: /content/archive/train/hot_dog/1046526.jpg
#   inflating: /content/archive/train/hot_dog/1051628.jpg
#   inflating: /content/archive/train/hot_dog/1051643.jpg
#   inflating: /content/archive/train/hot_dog/1051711.jpg
#   inflating: /content/archive/train/hot_dog/1053879.jpg
#   inflating: /content/archive/train/hot_dog/1055689.jpg
#   inflating: /content/archive/train/hot_dog/1057517.jpg
#   inflating: /content/archive/train/hot_dog/1057882.jpg
#   inflating: /content/archive/train/hot_dog/1059903.jpg
#   inflating: /content/archive/train/hot_dog/1068951.jpg
#   inflating: /content/archive/train/hot_dog/1086377.jpg
#   inflating: /content/archive/train/hot_dog/1086675.jpg
#   inflating: /content/archive/train/hot_dog/1086677.jpg
#   inflating: /content/archive/train/hot_dog/1098632.jpg
#   inflating: /content/archive/train/hot_dog/1098635.jpg
#   inflating: /content/archive/train/hot_dog/1104394.jpg
#   inflating: /content/archive/train/hot_dog/1107015.jpg
#   inflating: /content/archive/train/hot_dog/1111638.jpg
#   inflating: /content/archive/train/hot_dog/1114633.jpg
#   inflating: /content/archive/train/hot_dog/1115020.jpg
#   inflating: /content/archive/train/hot_dog/1119906.jpg
#   inflating: /content/archive/train/hot_dog/1123406.jpg
#   inflating: /content/archive/train/hot_dog/1125436.jpg
#   inflating: /content/archive/train/hot_dog/1133460.jpg
#   inflating: /content/archive/train/hot_dog/1134237.jpg
#   inflating: /content/archive/train/hot_dog/1143044.jpg
#   inflating: /content/archive/train/hot_dog/1143110.jpg
#   inflating: /content/archive/train/hot_dog/1143398.jpg
#   inflating: /content/archive/train/hot_dog/1143830.jpg
#   inflating: /content/archive/train/hot_dog/1144643.jpg
#   inflating: /content/archive/train/hot_dog/1153737.jpg
#   inflating: /content/archive/train/hot_dog/115434.jpg
#   inflating: /content/archive/train/hot_dog/1154965.jpg
#   inflating: /content/archive/train/hot_dog/1159972.jpg
#   inflating: /content/archive/train/hot_dog/1161343.jpg
#   inflating: /content/archive/train/hot_dog/1161755.jpg
#   inflating: /content/archive/train/hot_dog/116486.jpg
#   inflating: /content/archive/train/hot_dog/1166403.jpg
#   inflating: /content/archive/train/hot_dog/1166929.jpg
#   inflating: /content/archive/train/hot_dog/1174926.jpg
#   inflating: /content/archive/train/hot_dog/117749.jpg
#   inflating: /content/archive/train/hot_dog/1179964.jpg
#   inflating: /content/archive/train/hot_dog/1182402.jpg
#   inflating: /content/archive/train/hot_dog/1182518.jpg
#   inflating: /content/archive/train/hot_dog/1183508.jpg
#   inflating: /content/archive/train/hot_dog/1183725.jpg
#   inflating: /content/archive/train/hot_dog/1186993.jpg
#   inflating: /content/archive/train/hot_dog/118875.jpg
#   inflating: /content/archive/train/hot_dog/1190833.jpg
#   inflating: /content/archive/train/hot_dog/1192908.jpg
#   inflating: /content/archive/train/hot_dog/1195487.jpg
#   inflating: /content/archive/train/hot_dog/1195698.jpg
#   inflating: /content/archive/train/hot_dog/1195977.jpg
#   inflating: /content/archive/train/hot_dog/1204467.jpg
#   inflating: /content/archive/train/hot_dog/120471.jpg
#   inflating: /content/archive/train/hot_dog/1205205.jpg
#   inflating: /content/archive/train/hot_dog/1207811.jpg
#   inflating: /content/archive/train/hot_dog/1210977.jpg
#   inflating: /content/archive/train/hot_dog/1211682.jpg
#   inflating: /content/archive/train/hot_dog/122007.jpg
#   inflating: /content/archive/train/hot_dog/1224013.jpg
#   inflating: /content/archive/train/hot_dog/122606.jpg
#   inflating: /content/archive/train/hot_dog/1226430.jpg
#   inflating: /content/archive/train/hot_dog/1226791.jpg
#   inflating: /content/archive/train/hot_dog/1233688.jpg
#   inflating: /content/archive/train/hot_dog/1234491.jpg
#   inflating: /content/archive/train/hot_dog/1236871.jpg
#   inflating: /content/archive/train/hot_dog/124323.jpg
#   inflating: /content/archive/train/hot_dog/1245977.jpg
#   inflating: /content/archive/train/hot_dog/124987.jpg
#   inflating: /content/archive/train/hot_dog/1251087.jpg
#   inflating: /content/archive/train/hot_dog/1251173.jpg
#   inflating: /content/archive/train/hot_dog/1251741.jpg
#   inflating: /content/archive/train/hot_dog/125329.jpg
#   inflating: /content/archive/train/hot_dog/1265953.jpg
#   inflating: /content/archive/train/hot_dog/1267706.jpg
#   inflating: /content/archive/train/hot_dog/1268739.jpg
#   inflating: /content/archive/train/hot_dog/127117.jpg
#   inflating: /content/archive/train/hot_dog/127252.jpg
#   inflating: /content/archive/train/hot_dog/1282229.jpg
#   inflating: /content/archive/train/hot_dog/1282523.jpg
#   inflating: /content/archive/train/hot_dog/129092.jpg
#   inflating: /content/archive/train/hot_dog/1301907.jpg
#   inflating: /content/archive/train/hot_dog/1308699.jpg
#   inflating: /content/archive/train/hot_dog/1308879.jpg
#   inflating: /content/archive/train/hot_dog/1313978.jpg
#   inflating: /content/archive/train/hot_dog/1322860.jpg
#   inflating: /content/archive/train/hot_dog/1335350.jpg
#   inflating: /content/archive/train/hot_dog/1336262.jpg
#   inflating: /content/archive/train/hot_dog/1344141.jpg
#   inflating: /content/archive/train/hot_dog/1344958.jpg
#   inflating: /content/archive/train/hot_dog/1352514.jpg
#   inflating: /content/archive/train/hot_dog/1361187.jpg
#   inflating: /content/archive/train/hot_dog/1361606.jpg
#   inflating: /content/archive/train/hot_dog/1363093.jpg
#   inflating: /content/archive/train/hot_dog/1364019.jpg
#   inflating: /content/archive/train/hot_dog/2417.jpg
#   inflating: /content/archive/train/hot_dog/3493406.jpg
#   inflating: /content/archive/train/hot_dog/3494550.jpg
#   inflating: /content/archive/train/hot_dog/3495622.jpg
#   inflating: /content/archive/train/hot_dog/3497633.jpg
#   inflating: /content/archive/train/hot_dog/3497634.jpg
#   inflating: /content/archive/train/hot_dog/3497635.jpg
#   inflating: /content/archive/train/hot_dog/3503584.jpg
#   inflating: /content/archive/train/hot_dog/3503720.jpg
#   inflating: /content/archive/train/hot_dog/3525466.jpg
#   inflating: /content/archive/train/hot_dog/3527149.jpg
#   inflating: /content/archive/train/hot_dog/3538750.jpg
#   inflating: /content/archive/train/hot_dog/3543293.jpg
#   inflating: /content/archive/train/hot_dog/3552463.jpg
#   inflating: /content/archive/train/hot_dog/3552499.jpg
#   inflating: /content/archive/train/hot_dog/3558578.jpg
#   inflating: /content/archive/train/hot_dog/3568139.jpg
#   inflating: /content/archive/train/hot_dog/3575940.jpg
#   inflating: /content/archive/train/hot_dog/3577428.jpg
#   inflating: /content/archive/train/hot_dog/3620891.jpg
#   inflating: /content/archive/train/hot_dog/3622018.jpg
#   inflating: /content/archive/train/hot_dog/3628132.jpg
#   inflating: /content/archive/train/hot_dog/3636192.jpg
#   inflating: /content/archive/train/hot_dog/3637190.jpg
#   inflating: /content/archive/train/hot_dog/3639855.jpg
#   inflating: /content/archive/train/hot_dog/3642871.jpg
#   inflating: /content/archive/train/hot_dog/3645373.jpg
#   inflating: /content/archive/train/hot_dog/3646755.jpg
#   inflating: /content/archive/train/hot_dog/3655069.jpg
#   inflating: /content/archive/train/hot_dog/3655420.jpg
#   inflating: /content/archive/train/hot_dog/3660087.jpg
#   inflating: /content/archive/train/hot_dog/3684539.jpg
#   inflating: /content/archive/train/hot_dog/3690.jpg
#   inflating: /content/archive/train/hot_dog/3690427.jpg
#   inflating: /content/archive/train/hot_dog/3690925.jpg
#   inflating: /content/archive/train/hot_dog/3692506.jpg
#   inflating: /content/archive/train/hot_dog/3695334.jpg
#   inflating: /content/archive/train/hot_dog/3701301.jpg
#   inflating: /content/archive/train/hot_dog/3711230.jpg
#   inflating: /content/archive/train/hot_dog/3711747.jpg
#   inflating: /content/archive/train/hot_dog/3714525.jpg
#   inflating: /content/archive/train/hot_dog/3716190.jpg
#   inflating: /content/archive/train/hot_dog/3724744.jpg
#   inflating: /content/archive/train/hot_dog/3726090.jpg
#   inflating: /content/archive/train/hot_dog/3726741.jpg
#   inflating: /content/archive/train/hot_dog/3728106.jpg
#   inflating: /content/archive/train/hot_dog/3730066.jpg
#   inflating: /content/archive/train/hot_dog/3733563.jpg
#   inflating: /content/archive/train/hot_dog/3733809.jpg
#   inflating: /content/archive/train/hot_dog/3736382.jpg
#   inflating: /content/archive/train/hot_dog/3742819.jpg
#   inflating: /content/archive/train/hot_dog/3742960.jpg
#   inflating: /content/archive/train/hot_dog/3746979.jpg
#   inflating: /content/archive/train/hot_dog/3748381.jpg
#   inflating: /content/archive/train/hot_dog/3750744.jpg
#   inflating: /content/archive/train/hot_dog/3753950.jpg
#   inflating: /content/archive/train/hot_dog/3758438.jpg
#   inflating: /content/archive/train/hot_dog/3760604.jpg
#   inflating: /content/archive/train/hot_dog/3763491.jpg
#   inflating: /content/archive/train/hot_dog/3764724.jpg
#   inflating: /content/archive/train/hot_dog/3765729.jpg
#   inflating: /content/archive/train/hot_dog/3778004.jpg
#   inflating: /content/archive/train/hot_dog/3782895.jpg
#   inflating: /content/archive/train/hot_dog/3784903.jpg
#   inflating: /content/archive/train/hot_dog/3789403.jpg
#   inflating: /content/archive/train/hot_dog/3789737.jpg
#   inflating: /content/archive/train/hot_dog/3798465.jpg
#   inflating: /content/archive/train/hot_dog/3802333.jpg
#   inflating: /content/archive/train/hot_dog/3811761.jpg
#   inflating: /content/archive/train/hot_dog/3814644.jpg
#   inflating: /content/archive/train/hot_dog/3835641.jpg
#   inflating: /content/archive/train/hot_dog/3838014.jpg
#   inflating: /content/archive/train/hot_dog/3840582.jpg
#   inflating: /content/archive/train/hot_dog/3842701.jpg
#   inflating: /content/archive/train/hot_dog/3843212.jpg
#   inflating: /content/archive/train/hot_dog/3844876.jpg
#   inflating: /content/archive/train/hot_dog/3846249.jpg
#   inflating: /content/archive/train/hot_dog/3847258.jpg
#   inflating: /content/archive/train/hot_dog/3847289.jpg
#   inflating: /content/archive/train/hot_dog/3852193.jpg
#   inflating: /content/archive/train/hot_dog/3859916.jpg
#   inflating: /content/archive/train/hot_dog/3860703.jpg
#   inflating: /content/archive/train/hot_dog/3861791.jpg
#   inflating: /content/archive/train/hot_dog/3864679.jpg
#   inflating: /content/archive/train/hot_dog/3867396.jpg
#   inflating: /content/archive/train/hot_dog/3870911.jpg
#   inflating: /content/archive/train/hot_dog/3872613.jpg
#   inflating: /content/archive/train/hot_dog/3872738.jpg
#   inflating: /content/archive/train/hot_dog/3878668.jpg
#   inflating: /content/archive/train/hot_dog/3884328.jpg
#   inflating: /content/archive/train/hot_dog/3901819.jpg
#   inflating: /content/archive/train/hot_dog/3902792.jpg
#   inflating: /content/archive/train/hot_dog/3904556.jpg
#   inflating: /content/archive/train/hot_dog/3905030.jpg
#   inflating: /content/archive/train/hot_dog/3905238.jpg
#   inflating: /content/archive/train/hot_dog/3911675.jpg
#   inflating: /content/archive/train/hot_dog/3912870.jpg
#   inflating: /content/archive/train/hot_dog/3915296.jpg
#   inflating: /content/archive/train/hot_dog/3918223.jpg
#   inflating: /content/archive/train/hot_dog/5079.jpg
#   inflating: /content/archive/train/hot_dog/76722.jpg
#   inflating: /content/archive/train/hot_dog/7896.jpg
#   inflating: /content/archive/train/hot_dog/853994.jpg
#   inflating: /content/archive/train/hot_dog/856178.jpg
#   inflating: /content/archive/train/hot_dog/857110.jpg
#   inflating: /content/archive/train/hot_dog/864518.jpg
#   inflating: /content/archive/train/hot_dog/865184.jpg
#   inflating: /content/archive/train/hot_dog/867751.jpg
#   inflating: /content/archive/train/hot_dog/867991.jpg
#   inflating: /content/archive/train/hot_dog/869853.jpg
#   inflating: /content/archive/train/hot_dog/884796.jpg
#   inflating: /content/archive/train/hot_dog/888267.jpg
#   inflating: /content/archive/train/hot_dog/891949.jpg
#   inflating: /content/archive/train/hot_dog/893274.jpg
#   inflating: /content/archive/train/hot_dog/893996.jpg
#   inflating: /content/archive/train/hot_dog/898576.jpg
#   inflating: /content/archive/train/hot_dog/907088.jpg
#   inflating: /content/archive/train/hot_dog/910098.jpg
#   inflating: /content/archive/train/hot_dog/910827.jpg
#   inflating: /content/archive/train/hot_dog/916396.jpg
#   inflating: /content/archive/train/hot_dog/917699.jpg
#   inflating: /content/archive/train/hot_dog/920993.jpg
#   inflating: /content/archive/train/hot_dog/923240.jpg
#   inflating: /content/archive/train/hot_dog/926070.jpg
#   inflating: /content/archive/train/hot_dog/930181.jpg
#   inflating: /content/archive/train/hot_dog/930190.jpg
#   inflating: /content/archive/train/hot_dog/935952.jpg
#   inflating: /content/archive/train/hot_dog/938937.jpg
#   inflating: /content/archive/train/hot_dog/940404.jpg
#   inflating: /content/archive/train/hot_dog/941035.jpg
#   inflating: /content/archive/train/hot_dog/950384.jpg
#   inflating: /content/archive/train/hot_dog/950413.jpg
#   inflating: /content/archive/train/hot_dog/951103.jpg
#   inflating: /content/archive/train/hot_dog/952378.jpg
#   inflating: /content/archive/train/hot_dog/956229.jpg
#   inflating: /content/archive/train/hot_dog/958900.jpg
#   inflating: /content/archive/train/hot_dog/959883.jpg
#   inflating: /content/archive/train/hot_dog/961367.jpg
#   inflating: /content/archive/train/hot_dog/971944.jpg
#   inflating: /content/archive/train/hot_dog/974520.jpg
#   inflating: /content/archive/train/hot_dog/978158.jpg
#   inflating: /content/archive/train/hot_dog/978455.jpg
#   inflating: /content/archive/train/hot_dog/979767.jpg
#   inflating: /content/archive/train/hot_dog/987144.jpg
#   inflating: /content/archive/train/hot_dog/987193.jpg
#   inflating: /content/archive/train/hot_dog/996310.jpg
#    creating: /content/archive/train/not_hot_dog/
#   inflating: /content/archive/train/not_hot_dog/100135.jpg
#   inflating: /content/archive/train/not_hot_dog/100148.jpg
#   inflating: /content/archive/train/not_hot_dog/100274.jpg
#   inflating: /content/archive/train/not_hot_dog/100945.jpg
#   inflating: /content/archive/train/not_hot_dog/101312.jpg
#   inflating: /content/archive/train/not_hot_dog/102037.jpg
#   inflating: /content/archive/train/not_hot_dog/102197.jpg
#   inflating: /content/archive/train/not_hot_dog/102813.jpg
#   inflating: /content/archive/train/not_hot_dog/103010.jpg
#   inflating: /content/archive/train/not_hot_dog/105375.jpg
#   inflating: /content/archive/train/not_hot_dog/105647.jpg
#   inflating: /content/archive/train/not_hot_dog/106608.jpg
#   inflating: /content/archive/train/not_hot_dog/107013.jpg
#   inflating: /content/archive/train/not_hot_dog/107216.jpg
#   inflating: /content/archive/train/not_hot_dog/107312.jpg
#   inflating: /content/archive/train/not_hot_dog/107816.jpg
#   inflating: /content/archive/train/not_hot_dog/108310.jpg
#   inflating: /content/archive/train/not_hot_dog/108743.jpg
#   inflating: /content/archive/train/not_hot_dog/109401.jpg
#   inflating: /content/archive/train/not_hot_dog/109926.jpg
#   inflating: /content/archive/train/not_hot_dog/110171.jpg
#   inflating: /content/archive/train/not_hot_dog/110385.jpg
#   inflating: /content/archive/train/not_hot_dog/112309.jpg
#   inflating: /content/archive/train/not_hot_dog/113605.jpg
#   inflating: /content/archive/train/not_hot_dog/114269.jpg
#   inflating: /content/archive/train/not_hot_dog/114601.jpg
#   inflating: /content/archive/train/not_hot_dog/1164.jpg
#   inflating: /content/archive/train/not_hot_dog/1167.jpg
#   inflating: /content/archive/train/not_hot_dog/117282.jpg
#   inflating: /content/archive/train/not_hot_dog/118378.jpg
#   inflating: /content/archive/train/not_hot_dog/123902.jpg
#   inflating: /content/archive/train/not_hot_dog/123929.jpg
#   inflating: /content/archive/train/not_hot_dog/124128.jpg
#   inflating: /content/archive/train/not_hot_dog/126345.jpg
#   inflating: /content/archive/train/not_hot_dog/126784.jpg
#   inflating: /content/archive/train/not_hot_dog/127029.jpg
#   inflating: /content/archive/train/not_hot_dog/129045.jpg
#   inflating: /content/archive/train/not_hot_dog/129050.jpg
#   inflating: /content/archive/train/not_hot_dog/129730.jpg
#   inflating: /content/archive/train/not_hot_dog/130384.jpg
#   inflating: /content/archive/train/not_hot_dog/130766.jpg
#   inflating: /content/archive/train/not_hot_dog/134369.jpg
#   inflating: /content/archive/train/not_hot_dog/134598.jpg
#   inflating: /content/archive/train/not_hot_dog/136985.jpg
#   inflating: /content/archive/train/not_hot_dog/138514.jpg
#   inflating: /content/archive/train/not_hot_dog/138754.jpg
#   inflating: /content/archive/train/not_hot_dog/139291.jpg
#   inflating: /content/archive/train/not_hot_dog/140292.jpg
#   inflating: /content/archive/train/not_hot_dog/140832.jpg
#   inflating: /content/archive/train/not_hot_dog/141320.jpg
#   inflating: /content/archive/train/not_hot_dog/143158.jpg
#   inflating: /content/archive/train/not_hot_dog/143685.jpg
#   inflating: /content/archive/train/not_hot_dog/143994.jpg
#   inflating: /content/archive/train/not_hot_dog/145012.jpg
#   inflating: /content/archive/train/not_hot_dog/146029.jpg
#   inflating: /content/archive/train/not_hot_dog/146910.jpg
#   inflating: /content/archive/train/not_hot_dog/147312.jpg
#   inflating: /content/archive/train/not_hot_dog/147558.jpg
#   inflating: /content/archive/train/not_hot_dog/147599.jpg
#   inflating: /content/archive/train/not_hot_dog/147628.jpg
#   inflating: /content/archive/train/not_hot_dog/149278.jpg
#   inflating: /content/archive/train/not_hot_dog/152498.jpg
#   inflating: /content/archive/train/not_hot_dog/153387.jpg
#   inflating: /content/archive/train/not_hot_dog/153648.jpg
#   inflating: /content/archive/train/not_hot_dog/153823.jpg
#   inflating: /content/archive/train/not_hot_dog/157282.jpg
#   inflating: /content/archive/train/not_hot_dog/159745.jpg
#   inflating: /content/archive/train/not_hot_dog/160301.jpg
#   inflating: /content/archive/train/not_hot_dog/160494.jpg
#   inflating: /content/archive/train/not_hot_dog/160611.jpg
#   inflating: /content/archive/train/not_hot_dog/161122.jpg
#   inflating: /content/archive/train/not_hot_dog/163153.jpg
#   inflating: /content/archive/train/not_hot_dog/164288.jpg
#   inflating: /content/archive/train/not_hot_dog/166217.jpg
#   inflating: /content/archive/train/not_hot_dog/166821.jpg
#   inflating: /content/archive/train/not_hot_dog/167022.jpg
#   inflating: /content/archive/train/not_hot_dog/168924.jpg
#   inflating: /content/archive/train/not_hot_dog/172042.jpg
#   inflating: /content/archive/train/not_hot_dog/172593.jpg
#   inflating: /content/archive/train/not_hot_dog/173241.jpg
#   inflating: /content/archive/train/not_hot_dog/174045.jpg
#   inflating: /content/archive/train/not_hot_dog/174977.jpg
#   inflating: /content/archive/train/not_hot_dog/176667.jpg
#   inflating: /content/archive/train/not_hot_dog/177372.jpg
#   inflating: /content/archive/train/not_hot_dog/178804.jpg
#   inflating: /content/archive/train/not_hot_dog/179038.jpg
#   inflating: /content/archive/train/not_hot_dog/180453.jpg
#   inflating: /content/archive/train/not_hot_dog/181579.jpg
#   inflating: /content/archive/train/not_hot_dog/181677.jpg
#   inflating: /content/archive/train/not_hot_dog/182516.jpg
#   inflating: /content/archive/train/not_hot_dog/182658.jpg
#   inflating: /content/archive/train/not_hot_dog/183313.jpg
#   inflating: /content/archive/train/not_hot_dog/184954.jpg
#   inflating: /content/archive/train/not_hot_dog/185190.jpg
#   inflating: /content/archive/train/not_hot_dog/187087.jpg
#   inflating: /content/archive/train/not_hot_dog/188505.jpg
#   inflating: /content/archive/train/not_hot_dog/189482.jpg
#   inflating: /content/archive/train/not_hot_dog/189787.jpg
#   inflating: /content/archive/train/not_hot_dog/191085.jpg
#   inflating: /content/archive/train/not_hot_dog/191302.jpg
#   inflating: /content/archive/train/not_hot_dog/192132.jpg
#   inflating: /content/archive/train/not_hot_dog/192632.jpg
#   inflating: /content/archive/train/not_hot_dog/194973.jpg
#   inflating: /content/archive/train/not_hot_dog/197.jpg
#   inflating: /content/archive/train/not_hot_dog/198099.jpg
#   inflating: /content/archive/train/not_hot_dog/198445.jpg
#   inflating: /content/archive/train/not_hot_dog/200168.jpg
#   inflating: /content/archive/train/not_hot_dog/200448.jpg
#   inflating: /content/archive/train/not_hot_dog/200553.jpg
#   inflating: /content/archive/train/not_hot_dog/200639.jpg
#   inflating: /content/archive/train/not_hot_dog/201362.jpg
#   inflating: /content/archive/train/not_hot_dog/202247.jpg
#   inflating: /content/archive/train/not_hot_dog/203613.jpg
#   inflating: /content/archive/train/not_hot_dog/203924.jpg
#   inflating: /content/archive/train/not_hot_dog/204100.jpg
#   inflating: /content/archive/train/not_hot_dog/204132.jpg
#   inflating: /content/archive/train/not_hot_dog/204169.jpg
#   inflating: /content/archive/train/not_hot_dog/206271.jpg
#   inflating: /content/archive/train/not_hot_dog/211949.jpg
#   inflating: /content/archive/train/not_hot_dog/211973.jpg
#   inflating: /content/archive/train/not_hot_dog/212348.jpg
#   inflating: /content/archive/train/not_hot_dog/213387.jpg
#   inflating: /content/archive/train/not_hot_dog/215927.jpg
#   inflating: /content/archive/train/not_hot_dog/215931.jpg
#   inflating: /content/archive/train/not_hot_dog/217445.jpg
#   inflating: /content/archive/train/not_hot_dog/217607.jpg
#   inflating: /content/archive/train/not_hot_dog/219778.jpg
#   inflating: /content/archive/train/not_hot_dog/222138.jpg
#   inflating: /content/archive/train/not_hot_dog/222586.jpg
#   inflating: /content/archive/train/not_hot_dog/223676.jpg
#   inflating: /content/archive/train/not_hot_dog/223944.jpg
#   inflating: /content/archive/train/not_hot_dog/225525.jpg
#   inflating: /content/archive/train/not_hot_dog/225804.jpg
#   inflating: /content/archive/train/not_hot_dog/230015.jpg
#   inflating: /content/archive/train/not_hot_dog/232844.jpg
#   inflating: /content/archive/train/not_hot_dog/233172.jpg
#   inflating: /content/archive/train/not_hot_dog/234706.jpg
#   inflating: /content/archive/train/not_hot_dog/236973.jpg
#   inflating: /content/archive/train/not_hot_dog/238410.jpg
#   inflating: /content/archive/train/not_hot_dog/239724.jpg
#   inflating: /content/archive/train/not_hot_dog/240760.jpg
#   inflating: /content/archive/train/not_hot_dog/244006.jpg
#   inflating: /content/archive/train/not_hot_dog/244609.jpg
#   inflating: /content/archive/train/not_hot_dog/246510.jpg
#   inflating: /content/archive/train/not_hot_dog/249430.jpg
#   inflating: /content/archive/train/not_hot_dog/250720.jpg
#   inflating: /content/archive/train/not_hot_dog/251128.jpg
#   inflating: /content/archive/train/not_hot_dog/256347.jpg
#   inflating: /content/archive/train/not_hot_dog/258877.jpg
#   inflating: /content/archive/train/not_hot_dog/262882.jpg
#   inflating: /content/archive/train/not_hot_dog/265743.jpg
#   inflating: /content/archive/train/not_hot_dog/266364.jpg
#   inflating: /content/archive/train/not_hot_dog/267713.jpg
#   inflating: /content/archive/train/not_hot_dog/270122.jpg
#   inflating: /content/archive/train/not_hot_dog/274368.jpg
#   inflating: /content/archive/train/not_hot_dog/274711.jpg
#   inflating: /content/archive/train/not_hot_dog/275673.jpg
#   inflating: /content/archive/train/not_hot_dog/284999.jpg
#   inflating: /content/archive/train/not_hot_dog/289256.jpg
#   inflating: /content/archive/train/not_hot_dog/290229.jpg
#   inflating: /content/archive/train/not_hot_dog/290382.jpg
#   inflating: /content/archive/train/not_hot_dog/291636.jpg
#   inflating: /content/archive/train/not_hot_dog/292607.jpg
#   inflating: /content/archive/train/not_hot_dog/293052.jpg
#   inflating: /content/archive/train/not_hot_dog/296039.jpg
#   inflating: /content/archive/train/not_hot_dog/296611.jpg
#   inflating: /content/archive/train/not_hot_dog/302329.jpg
#   inflating: /content/archive/train/not_hot_dog/303460.jpg
#   inflating: /content/archive/train/not_hot_dog/303809.jpg
#   inflating: /content/archive/train/not_hot_dog/309651.jpg
#   inflating: /content/archive/train/not_hot_dog/311779.jpg
#   inflating: /content/archive/train/not_hot_dog/319830.jpg
#   inflating: /content/archive/train/not_hot_dog/320734.jpg
#   inflating: /content/archive/train/not_hot_dog/322067.jpg
#   inflating: /content/archive/train/not_hot_dog/331674.jpg
#   inflating: /content/archive/train/not_hot_dog/333385.jpg
#   inflating: /content/archive/train/not_hot_dog/338101.jpg
#   inflating: /content/archive/train/not_hot_dog/4176.jpg
#   inflating: /content/archive/train/not_hot_dog/4770.jpg
#   inflating: /content/archive/train/not_hot_dog/4781.jpg
#   inflating: /content/archive/train/not_hot_dog/4889.jpg
#   inflating: /content/archive/train/not_hot_dog/5762.jpg
#   inflating: /content/archive/train/not_hot_dog/5764.jpg
#   inflating: /content/archive/train/not_hot_dog/5813.jpg
#   inflating: /content/archive/train/not_hot_dog/6021.jpg
#   inflating: /content/archive/train/not_hot_dog/6127.jpg
#   inflating: /content/archive/train/not_hot_dog/748088.jpg
#   inflating: /content/archive/train/not_hot_dog/749374.jpg
#   inflating: /content/archive/train/not_hot_dog/759160.jpg
#   inflating: /content/archive/train/not_hot_dog/765053.jpg
#   inflating: /content/archive/train/not_hot_dog/766638.jpg
#   inflating: /content/archive/train/not_hot_dog/768793.jpg
#   inflating: /content/archive/train/not_hot_dog/769437.jpg
#   inflating: /content/archive/train/not_hot_dog/776077.jpg
#   inflating: /content/archive/train/not_hot_dog/779193.jpg
#   inflating: /content/archive/train/not_hot_dog/781137.jpg
#   inflating: /content/archive/train/not_hot_dog/784510.jpg
#   inflating: /content/archive/train/not_hot_dog/790763.jpg
#   inflating: /content/archive/train/not_hot_dog/791662.jpg
#   inflating: /content/archive/train/not_hot_dog/796326.jpg
#   inflating: /content/archive/train/not_hot_dog/797686.jpg
#   inflating: /content/archive/train/not_hot_dog/801827.jpg
#   inflating: /content/archive/train/not_hot_dog/803895.jpg
#   inflating: /content/archive/train/not_hot_dog/807258.jpg
#   inflating: /content/archive/train/not_hot_dog/815394.jpg
#   inflating: /content/archive/train/not_hot_dog/816725.jpg
#   inflating: /content/archive/train/not_hot_dog/816756.jpg
#   inflating: /content/archive/train/not_hot_dog/817533.jpg
#   inflating: /content/archive/train/not_hot_dog/822411.jpg
#   inflating: /content/archive/train/not_hot_dog/823536.jpg
#   inflating: /content/archive/train/not_hot_dog/824157.jpg
#   inflating: /content/archive/train/not_hot_dog/828189.jpg
#   inflating: /content/archive/train/not_hot_dog/835998.jpg
#   inflating: /content/archive/train/not_hot_dog/837058.jpg
#   inflating: /content/archive/train/not_hot_dog/846311.jpg
#   inflating: /content/archive/train/not_hot_dog/89197.jpg
#   inflating: /content/archive/train/not_hot_dog/89502.jpg
#   inflating: /content/archive/train/not_hot_dog/89892.jpg
#   inflating: /content/archive/train/not_hot_dog/89974.jpg
#   inflating: /content/archive/train/not_hot_dog/90116.jpg
#   inflating: /content/archive/train/not_hot_dog/90167.jpg
#   inflating: /content/archive/train/not_hot_dog/90481.jpg
#   inflating: /content/archive/train/not_hot_dog/90923.jpg
#   inflating: /content/archive/train/not_hot_dog/90930.jpg
#   inflating: /content/archive/train/not_hot_dog/90989.jpg
#   inflating: /content/archive/train/not_hot_dog/91432.jpg
#   inflating: /content/archive/train/not_hot_dog/91708.jpg
#   inflating: /content/archive/train/not_hot_dog/92128.jpg
#   inflating: /content/archive/train/not_hot_dog/92235.jpg
#   inflating: /content/archive/train/not_hot_dog/92331.jpg
#   inflating: /content/archive/train/not_hot_dog/93653.jpg
#   inflating: /content/archive/train/not_hot_dog/93961.jpg
#   inflating: /content/archive/train/not_hot_dog/94215.jpg
#   inflating: /content/archive/train/not_hot_dog/95565.jpg
#   inflating: /content/archive/train/not_hot_dog/95572.jpg
#   inflating: /content/archive/train/not_hot_dog/96213.jpg
#   inflating: /content/archive/train/not_hot_dog/96357.jpg
#   inflating: /content/archive/train/not_hot_dog/96524.jpg
#   inflating: /content/archive/train/not_hot_dog/96935.jpg
#   inflating: /content/archive/train/not_hot_dog/97656.jpg
#   inflating: /content/archive/train/not_hot_dog/98607.jpg
#   inflating: /content/archive/train/not_hot_dog/98617.jpg
#   inflating: /content/archive/train/not_hot_dog/98675.jpg
#   inflating: /content/archive/train/not_hot_dog/99010.jpg
#   inflating: /content/archive/train/not_hot_dog/99136.jpg
#   inflating: /content/archive/train/not_hot_dog/99201.jpg
#   inflating: /content/archive/train/not_hot_dog/99604.jpg
#   inflating: /content/archive/train/not_hot_dog/99890.jpg
#   inflating: /content/archive/train/not_hot_dog/99934.jpg

# %%
train_dataset = datasets.ImageFolder(
    root=r'/content/archive/train',
    transform=train_transform
)
train_dataloader = torch.utils.data.DataLoader(
    train_dataset, batch_size=32, shuffle=True,
)
val_dataset = datasets.ImageFolder(
    root=r'/content/archive/test',
    transform=val_transform
)
val_dataloader = torch.utils.data.DataLoader(
    val_dataset, batch_size=32, shuffle=False,
)

# %%
def resnet50(pretrained=True):
    model = models.resnet50(progress=True, pretrained=pretrained)
    if requires_grad == False:
        for param in model.parameters():
            param.requires_grad = False
    elif requires_grad == True:
        for param in model.parameters():
            param.requires_grad = True
    model.fc = nn.Linear(2048, 2)
    return model

# %%
class LRScheduler():
    def __init__(
        self, optimizer, patience=5, min_lr=1e-6, factor=0.5
    ):
        self.optimizer = optimizer
        self.patience = patience
        self.min_lr = min_lr
        self.factor = factor
        self.lr_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
                self.optimizer,
                mode='min',
                patience=self.patience,
                factor=self.factor,
                min_lr=self.min_lr,
                verbose=True
            )
    def __call__(self, val_loss):
        self.lr_scheduler.step(val_loss)

# %%
class EarlyStopping():
    def __init__(self, patience=5, verbose=False, delta=0, path='/content/checkpoint.pt'):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.delta = delta
        self.path = path

    def __call__(self, val_loss, model):
        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss

# %%
parser = argparse.ArgumentParser()
parser.add_argument('--lr-scheduler', dest='lr_scheduler', action='store_true')
parser.add_argument('--early-stopping', dest='early_stopping', action='store_true')
parser.add_argument("-f", "--fff", help="a dummy argument to fool ipython", default="1")
args = vars(parser.parse_args())

# %%
print(f"Computation device: {device}\n")
model = models.resnet50(pretrained=True).to(device)
total_params = sum(p.numel() for p in model.parameters())
print(f"{total_params:,} total parameters.")
total_trainable_params = sum(
    p.numel() for p in model.parameters() if p.requires_grad)
print(f"{total_trainable_params:,} training parameters.")
# Out:
# Computation device: cuda
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:01<00:00, 64.3MB/s]
# 25,557,032 total parameters.
# 25,557,032 training parameters.

# %%
lr = 0.001
epochs = 100
optimizer = optim.Adam(model.parameters(), lr=lr)
criterion = nn.CrossEntropyLoss()

# %%
loss_plot_name = 'loss'
acc_plot_name = 'accuracy'
model_name = 'model'

# %%
if args['lr_scheduler']:
    print('INFO: Initializing learning rate scheduler')
    lr_scheduler = LRScheduler(optimizer)
    loss_plot_name = 'lrs_loss'
    acc_plot_name = 'lrs_accuracy'
    model_name = 'lrs_model'
if args['early_stopping']:
    print('INFO: Initializing early stopping')
    early_stopping = EarlyStopping()
    loss_plot_name = 'es_loss'
    acc_plot_name = 'es_accuracy'
    model_name = 'es_model'

# %%
def training(model, train_dataloader, train_dataset, optimizer, criterion):
    print('Training')
    model.train()
    train_running_loss = 0.0
    train_running_correct = 0
    counter = 0
    total = 0
    prog_bar = tqdm(enumerate(train_dataloader), total=int(len(train_dataset)/train_dataloader.batch_size))
    for i, data in prog_bar:
        counter += 1
        data, target = data[0].to(device), data[1].to(device)
        total += target.size(0)
        optimizer.zero_grad()
        outputs = model(data)
        loss = criterion(outputs, target)
        train_running_loss += loss.item()
        _, preds = torch.max(outputs.data, 1)
        train_running_correct += (preds == target).sum().item()
        loss.backward()
        optimizer.step()

    train_loss = train_running_loss / counter
    train_accuracy = 100. * train_running_correct / total
    return train_loss, train_accuracy

# %%
def validate(model, test_dataloader, val_dataset, criterion):
    print('Validating')
    model.eval()
    val_running_loss = 0.0
    val_running_correct = 0
    counter = 0
    total = 0
    prog_bar = tqdm(enumerate(test_dataloader), total=int(len(val_dataset)/test_dataloader.batch_size))
    with torch.no_grad():
        for i, data in prog_bar:
            counter += 1
            data, target = data[0].to(device), data[1].to(device)
            total += target.size(0)
            outputs = model(data)
            loss = criterion(outputs, target)

            val_running_loss += loss.item()
            _, preds = torch.max(outputs.data, 1)
            val_running_correct += (preds == target).sum().item()

        val_loss = val_running_loss / counter
        val_accuracy = 100. * val_running_correct / total
        return val_loss, val_accuracy

# %%
train_loss, train_accuracy = [], []
val_loss, val_accuracy = [], []
start = time.time()
for epoch in range(epochs):
    print(f"Epoch {epoch+1} of {epochs}")
    train_epoch_loss, train_epoch_accuracy = training(
        model, train_dataloader, train_dataset, optimizer, criterion
    )
    val_epoch_loss, val_epoch_accuracy = validate(
        model, val_dataloader, val_dataset, criterion
    )
    train_loss.append(train_epoch_loss)
    train_accuracy.append(train_epoch_accuracy)
    val_loss.append(val_epoch_loss)
    val_accuracy.append(val_epoch_accuracy)
    if args['lr_scheduler']:
        lr_scheduler(val_epoch_loss)
    if args['early_stopping']:
        early_stopping(val_epoch_loss, model)
        if early_stopping.early_stop:
            break
    print(f"Train Loss: {train_epoch_loss:.4f}, Train Acc: {train_epoch_accuracy:.2f}")
    print(f'Val Loss: {val_epoch_loss:.4f}, Val Acc: {val_epoch_accuracy:.2f}')
end = time.time()
print(f"Training time: {(end-start)/60:.3f} minutes")
# Out:
# Epoch 1 of 100
# Training
# 16it [00:06,  2.47it/s]
# Validating
# 16it [00:03,  4.73it/s]
# Train Loss: 2.1072, Train Acc: 58.63
# Val Loss: 19.5940, Val Acc: 49.00
# Epoch 2 of 100
# Training
# 16it [00:04,  3.57it/s]
# Validating
# 16it [00:03,  4.17it/s]
# Train Loss: 0.5749, Train Acc: 75.30
# Val Loss: 0.6959, Val Acc: 65.20
# Epoch 3 of 100
# Training
# 16it [00:04,  3.50it/s]
# Validating
# 16it [00:03,  4.82it/s]
# Train Loss: 0.4346, Train Acc: 81.53
# Val Loss: 0.5253, Val Acc: 77.40
# Epoch 4 of 100
# Training
# 16it [00:04,  3.40it/s]
# Validating
# 16it [00:03,  4.76it/s]
# Train Loss: 0.3715, Train Acc: 83.33
# Val Loss: 0.6125, Val Acc: 73.60
# Epoch 5 of 100
# Training
# 16it [00:04,  3.54it/s]
# Validating
# 16it [00:03,  4.28it/s]
# Train Loss: 0.3078, Train Acc: 87.55
# Val Loss: 0.4805, Val Acc: 81.20
# Epoch 6 of 100
# Training
# 16it [00:04,  3.46it/s]
# Validating
# 16it [00:03,  4.70it/s]
# Train Loss: 0.2381, Train Acc: 88.76
# Val Loss: 0.5934, Val Acc: 76.20
# Epoch 7 of 100
# Training
# 16it [00:04,  3.20it/s]
# Validating
# 16it [00:03,  4.66it/s]
# Train Loss: 0.2045, Train Acc: 91.57
# Val Loss: 0.8267, Val Acc: 72.60
# Epoch 8 of 100
# Training
# 16it [00:04,  3.50it/s]
# Validating
# 16it [00:03,  4.12it/s]
# Train Loss: 0.3360, Train Acc: 87.35
# Val Loss: 1.1969, Val Acc: 68.20
# Epoch 9 of 100
# Training
# 16it [00:04,  3.50it/s]
# Validating
# 16it [00:03,  4.81it/s]
# Train Loss: 0.3019, Train Acc: 88.76
# Val Loss: 0.9575, Val Acc: 69.60
# Epoch 10 of 100
# Training
# 16it [00:04,  3.37it/s]
# Validating
# 16it [00:03,  4.71it/s]
# Train Loss: 0.2373, Train Acc: 91.77
# Val Loss: 0.5921, Val Acc: 80.60
# Epoch 11 of 100
# Training
# 16it [00:04,  3.49it/s]
# Validating
# 16it [00:03,  4.05it/s]
# Train Loss: 0.1827, Train Acc: 92.57
# Val Loss: 0.9599, Val Acc: 70.20
# Epoch 12 of 100
# Training
# 16it [00:04,  3.48it/s]
# Validating
# 16it [00:03,  4.65it/s]
# Train Loss: 0.1353, Train Acc: 95.18
# Val Loss: 0.7535, Val Acc: 76.00
# Epoch 13 of 100
# Training
# 16it [00:04,  3.35it/s]
# Validating
# 16it [00:03,  4.78it/s]
# Train Loss: 0.1699, Train Acc: 94.98
# Val Loss: 0.6084, Val Acc: 78.00
# Epoch 14 of 100
# Training
# 16it [00:04,  3.46it/s]
# Validating
# 16it [00:03,  4.12it/s]
# Train Loss: 0.1624, Train Acc: 94.18
# Val Loss: 0.5382, Val Acc: 81.00
# Epoch 15 of 100
# Training
# 16it [00:04,  3.44it/s]
# Validating
# 16it [00:03,  4.77it/s]
# Train Loss: 0.1616, Train Acc: 93.57
# Val Loss: 0.8327, Val Acc: 75.40
# Epoch 16 of 100
# Training
# 16it [00:04,  3.32it/s]
# Validating
# 16it [00:03,  4.69it/s]
# Train Loss: 0.1914, Train Acc: 92.17
# Val Loss: 1.1484, Val Acc: 74.80
# Epoch 17 of 100
# Training
# 16it [00:04,  3.44it/s]
# Validating
# 16it [00:03,  4.01it/s]
# Train Loss: 0.1449, Train Acc: 93.98
# Val Loss: 1.2745, Val Acc: 67.20
# Epoch 18 of 100
# Training
# 16it [00:04,  3.43it/s]
# Validating
# 16it [00:03,  4.69it/s]
# Train Loss: 0.1065, Train Acc: 96.79
# Val Loss: 0.6441, Val Acc: 77.80
# Epoch 19 of 100
# Training
# 16it [00:04,  3.27it/s]
# Validating
# 16it [00:03,  4.69it/s]
# Train Loss: 0.1486, Train Acc: 94.78
# Val Loss: 0.9411, Val Acc: 74.40
# Epoch 20 of 100
# Training
# 16it [00:04,  3.42it/s]
# Validating
# 16it [00:03,  4.02it/s]
# Train Loss: 0.2082, Train Acc: 91.77
# Val Loss: 1.4276, Val Acc: 72.20
# Epoch 21 of 100
# Training
# 16it [00:04,  3.42it/s]
# Validating
# 16it [00:03,  4.76it/s]
# Train Loss: 0.3000, Train Acc: 89.96
# Val Loss: 0.7482, Val Acc: 75.40
# Epoch 22 of 100
# Training
# 16it [00:04,  3.27it/s]
# Validating
# 16it [00:03,  4.67it/s]
# Train Loss: 0.2012, Train Acc: 92.17
# Val Loss: 0.6551, Val Acc: 77.20
# Epoch 23 of 100
# Training
# 16it [00:04,  3.40it/s]
# Validating
# 16it [00:03,  4.24it/s]
# Train Loss: 0.1522, Train Acc: 94.18
# Val Loss: 1.1952, Val Acc: 68.00
# Epoch 24 of 100
# Training
# 16it [00:04,  3.42it/s]
# Validating
# 16it [00:03,  4.49it/s]
# Train Loss: 0.1330, Train Acc: 95.78
# Val Loss: 0.7286, Val Acc: 77.00
# Epoch 25 of 100
# Training
# 16it [00:04,  3.26it/s]
# Validating
# 16it [00:03,  4.72it/s]
# Train Loss: 0.1822, Train Acc: 94.58
# Val Loss: 0.8025, Val Acc: 76.80
# Epoch 26 of 100
# Training
# 16it [00:04,  3.37it/s]
# Validating
# 16it [00:03,  4.41it/s]
# Train Loss: 0.1348, Train Acc: 94.58
# Val Loss: 0.6867, Val Acc: 77.80
# Epoch 27 of 100
# Training
# 16it [00:04,  3.39it/s]
# Validating
# 16it [00:03,  4.30it/s]
# Train Loss: 0.1335, Train Acc: 95.18
# Val Loss: 0.7601, Val Acc: 74.60
# Epoch 28 of 100
# Training
# 16it [00:04,  3.30it/s]
# Validating
# 16it [00:03,  4.66it/s]
# Train Loss: 0.1392, Train Acc: 94.98
# Val Loss: 0.5853, Val Acc: 76.80
# Epoch 29 of 100
# Training
# 16it [00:04,  3.29it/s]
# Validating
# 16it [00:03,  4.71it/s]
# Train Loss: 0.0617, Train Acc: 98.19
# Val Loss: 0.5418, Val Acc: 81.80
# Epoch 30 of 100
# Training
# 16it [00:04,  3.39it/s]
# Validating
# 16it [00:03,  4.09it/s]
# Train Loss: 0.0541, Train Acc: 98.19
# Val Loss: 0.6414, Val Acc: 81.40
# Epoch 31 of 100
# Training
# 16it [00:04,  3.38it/s]
# Validating
# 16it [00:03,  4.65it/s]
# Train Loss: 0.0415, Train Acc: 98.39
# Val Loss: 1.1960, Val Acc: 72.20
# Epoch 32 of 100
# Training
# 16it [00:04,  3.29it/s]
# Validating
# 16it [00:03,  4.66it/s]
# Train Loss: 0.0798, Train Acc: 96.39
# Val Loss: 0.7872, Val Acc: 76.80
# Epoch 33 of 100
# Training
# 16it [00:04,  3.38it/s]
# Validating
# 16it [00:03,  4.06it/s]
# Train Loss: 0.0770, Train Acc: 97.39
# Val Loss: 0.7879, Val Acc: 77.40
# Epoch 34 of 100
# Training
# 16it [00:04,  3.39it/s]
# Validating
# 16it [00:03,  4.67it/s]
# Train Loss: 0.0892, Train Acc: 97.59
# Val Loss: 0.7472, Val Acc: 77.00
# Epoch 35 of 100
# Training
# 16it [00:04,  3.28it/s]
# Validating
# 16it [00:03,  4.71it/s]
# Train Loss: 0.0815, Train Acc: 97.19
# Val Loss: 0.9342, Val Acc: 75.00
# Epoch 36 of 100
# Training
# 16it [00:04,  3.38it/s]
# Validating
# 16it [00:03,  4.05it/s]
# Train Loss: 0.0416, Train Acc: 97.99
# Val Loss: 1.8434, Val Acc: 67.80
# Epoch 37 of 100
# Training
# 16it [00:04,  3.37it/s]
# Validating
# 16it [00:03,  4.70it/s]
# Train Loss: 0.1132, Train Acc: 96.79
# Val Loss: 1.3094, Val Acc: 70.00
# Epoch 38 of 100
# Training
# 16it [00:04,  3.28it/s]
# Validating
# 16it [00:03,  4.75it/s]
# Train Loss: 0.0551, Train Acc: 97.79
# Val Loss: 0.7119, Val Acc: 80.00
# Epoch 39 of 100
# Training
# 16it [00:04,  3.38it/s]
# Validating
# 16it [00:03,  4.12it/s]
# Train Loss: 0.0440, Train Acc: 98.80
# Val Loss: 0.7085, Val Acc: 79.40
# Epoch 40 of 100
# Training
# 16it [00:04,  3.37it/s]
# Validating
# 16it [00:03,  4.61it/s]
# Train Loss: 0.0490, Train Acc: 99.00
# Val Loss: 0.7797, Val Acc: 79.40
# Epoch 41 of 100
# Training
# 16it [00:04,  3.23it/s]
# Validating
# 16it [00:03,  4.72it/s]
# Train Loss: 0.0914, Train Acc: 96.59
# Val Loss: 0.9152, Val Acc: 78.20
# Epoch 42 of 100
# Training
# 16it [00:04,  3.33it/s]
# Validating
# 16it [00:03,  4.44it/s]
# Train Loss: 0.1283, Train Acc: 95.98
# Val Loss: 0.9149, Val Acc: 76.80
# Epoch 43 of 100
# Training
# 16it [00:04,  3.37it/s]
# Validating
# 16it [00:03,  4.33it/s]
# Train Loss: 0.0893, Train Acc: 96.59
# Val Loss: 0.7579, Val Acc: 74.80
# Epoch 44 of 100
# Training
# 16it [00:04,  3.27it/s]
# Validating
# 16it [00:03,  4.67it/s]
# Train Loss: 0.0802, Train Acc: 96.79
# Val Loss: 1.8428, Val Acc: 71.00
# Epoch 45 of 100
# Training
# 16it [00:04,  3.26it/s]
# Validating
# 16it [00:03,  4.70it/s]
# Train Loss: 0.0546, Train Acc: 97.99
# Val Loss: 1.3154, Val Acc: 69.40
# Epoch 46 of 100
# Training
# 16it [00:04,  3.37it/s]
# Validating
# 16it [00:03,  4.09it/s]
# Train Loss: 0.0895, Train Acc: 96.39
# Val Loss: 0.9541, Val Acc: 77.60
# Epoch 47 of 100
# Training
# 16it [00:04,  3.36it/s]
# Validating
# 16it [00:03,  4.74it/s]
# Train Loss: 0.1285, Train Acc: 95.98
# Val Loss: 1.0789, Val Acc: 73.20
# Epoch 48 of 100
# Training
# 16it [00:04,  3.27it/s]
# Validating
# 16it [00:03,  4.71it/s]
# Train Loss: 0.1053, Train Acc: 96.39
# Val Loss: 0.9967, Val Acc: 74.40
# Epoch 49 of 100
# Training
# 16it [00:04,  3.37it/s]
# Validating
# 16it [00:03,  4.05it/s]
# Train Loss: 0.1383, Train Acc: 94.78
# Val Loss: 0.8047, Val Acc: 79.60
# Epoch 50 of 100
# Training
# 16it [00:04,  3.37it/s]
# Validating
# 16it [00:03,  4.71it/s]
# Train Loss: 0.0553, Train Acc: 97.99
# Val Loss: 0.7221, Val Acc: 78.60
# Epoch 51 of 100
# Training
# 16it [00:04,  3.27it/s]
# Validating
# 16it [00:03,  4.66it/s]
# Train Loss: 0.0537, Train Acc: 98.39
# Val Loss: 0.9070, Val Acc: 77.40
# Epoch 52 of 100
# Training
# 16it [00:04,  3.36it/s]
# Validating
# 16it [00:03,  4.03it/s]
# Train Loss: 0.0992, Train Acc: 96.59
# Val Loss: 0.8162, Val Acc: 78.00
# Epoch 53 of 100
# Training
# 16it [00:04,  3.36it/s]
# Validating
# 16it [00:03,  4.70it/s]
# Train Loss: 0.0955, Train Acc: 96.39
# Val Loss: 0.9532, Val Acc: 75.00
# Epoch 54 of 100
# Training
# 16it [00:04,  3.25it/s]
# Validating
# 16it [00:03,  4.66it/s]
# Train Loss: 0.1069, Train Acc: 95.58
# Val Loss: 0.9397, Val Acc: 71.80
# Epoch 55 of 100
# Training
# 16it [00:04,  3.34it/s]
# Validating
# 16it [00:03,  4.20it/s]
# Train Loss: 0.1394, Train Acc: 95.78
# Val Loss: 1.3132, Val Acc: 72.60
# Epoch 56 of 100
# Training
# 16it [00:04,  3.36it/s]
# Validating
# 16it [00:03,  4.45it/s]
# Train Loss: 0.0963, Train Acc: 94.98
# Val Loss: 0.8310, Val Acc: 74.40
# Epoch 57 of 100
# Training
# 16it [00:04,  3.25it/s]
# Validating
# 16it [00:03,  4.75it/s]
# Train Loss: 0.0700, Train Acc: 96.99
# Val Loss: 0.8879, Val Acc: 77.00
# Epoch 58 of 100
# Training
# 16it [00:04,  3.31it/s]
# Validating
# 16it [00:03,  4.57it/s]
# Train Loss: 0.0502, Train Acc: 98.19
# Val Loss: 0.7900, Val Acc: 78.20
# Epoch 59 of 100
# Training
# 16it [00:04,  3.37it/s]
# Validating
# 16it [00:03,  4.29it/s]
# Train Loss: 0.0574, Train Acc: 96.99
# Val Loss: 0.7864, Val Acc: 80.00
# Epoch 60 of 100
# Training
# 16it [00:04,  3.27it/s]
# Validating
# 16it [00:03,  4.70it/s]
# Train Loss: 0.0761, Train Acc: 97.19
# Val Loss: 0.6574, Val Acc: 79.80
# Epoch 61 of 100
# Training
# 16it [00:04,  3.24it/s]
# Validating
# 16it [00:03,  4.67it/s]
# Train Loss: 0.0711, Train Acc: 97.79
# Val Loss: 0.5844, Val Acc: 81.00
# Epoch 62 of 100
# Training
# 16it [00:04,  3.35it/s]
# Validating
# 16it [00:03,  4.15it/s]
# Train Loss: 0.0428, Train Acc: 98.59
# Val Loss: 1.0214, Val Acc: 74.00
# Epoch 63 of 100
# Training
# 16it [00:04,  3.36it/s]
# Validating
# 16it [00:03,  4.73it/s]
# Train Loss: 0.0297, Train Acc: 99.20
# Val Loss: 0.7586, Val Acc: 79.80
# Epoch 64 of 100
# Training
# 16it [00:04,  3.29it/s]
# Validating
# 16it [00:03,  4.71it/s]
# Train Loss: 0.0635, Train Acc: 98.39
# Val Loss: 1.6584, Val Acc: 72.00
# Epoch 65 of 100
# Training
# 16it [00:04,  3.36it/s]
# Validating
# 16it [00:03,  4.10it/s]
# Train Loss: 0.0552, Train Acc: 97.79
# Val Loss: 0.9317, Val Acc: 75.60
# Epoch 66 of 100
# Training
# 16it [00:04,  3.36it/s]
# Validating
# 16it [00:03,  4.70it/s]
# Train Loss: 0.0378, Train Acc: 98.39
# Val Loss: 0.8049, Val Acc: 75.80
# Epoch 67 of 100
# Training
# 16it [00:04,  3.27it/s]
# Validating
# 16it [00:03,  4.72it/s]
# Train Loss: 0.0570, Train Acc: 97.99
# Val Loss: 1.8631, Val Acc: 68.60
# Epoch 68 of 100
# Training
# 16it [00:04,  3.35it/s]
# Validating
# 16it [00:03,  4.07it/s]
# Train Loss: 0.0856, Train Acc: 97.19
# Val Loss: 2.1964, Val Acc: 67.80
# Epoch 69 of 100
# Training
# 16it [00:04,  3.37it/s]
# Validating
# 16it [00:03,  4.66it/s]
# Train Loss: 0.0760, Train Acc: 97.39
# Val Loss: 0.9701, Val Acc: 77.80
# Epoch 70 of 100
# Training
# 16it [00:04,  3.22it/s]
# Validating
# 16it [00:03,  4.69it/s]
# Train Loss: 0.0431, Train Acc: 98.59
# Val Loss: 1.0947, Val Acc: 76.00
# Epoch 71 of 100
# Training
# 16it [00:04,  3.32it/s]
# Validating
# 16it [00:03,  4.28it/s]
# Train Loss: 0.0402, Train Acc: 99.20
# Val Loss: 1.0466, Val Acc: 73.60
# Epoch 72 of 100
# Training
# 16it [00:04,  3.36it/s]
# Validating
# 16it [00:03,  4.40it/s]
# Train Loss: 0.0531, Train Acc: 97.59
# Val Loss: 1.0638, Val Acc: 75.80
# Epoch 73 of 100
# Training
# 16it [00:04,  3.23it/s]
# Validating
# 16it [00:03,  4.67it/s]
# Train Loss: 0.0584, Train Acc: 97.99
# Val Loss: 0.6542, Val Acc: 83.60
# Epoch 74 of 100
# Training
# 16it [00:04,  3.28it/s]
# Validating
# 16it [00:03,  4.64it/s]
# Train Loss: 0.0702, Train Acc: 96.99
# Val Loss: 1.0316, Val Acc: 75.40
# Epoch 75 of 100
# Training
# 16it [00:04,  3.35it/s]
# Validating
# 16it [00:03,  4.07it/s]
# Train Loss: 0.0475, Train Acc: 97.79
# Val Loss: 1.0351, Val Acc: 75.40
# Epoch 76 of 100
# Training
# 16it [00:04,  3.33it/s]
# Validating
# 16it [00:03,  4.67it/s]
# Train Loss: 0.0429, Train Acc: 97.99
# Val Loss: 1.1574, Val Acc: 73.40
# Epoch 77 of 100
# Training
# 16it [00:04,  3.27it/s]
# Validating
# 16it [00:03,  4.72it/s]
# Train Loss: 0.0384, Train Acc: 98.59
# Val Loss: 0.8128, Val Acc: 78.00
# Epoch 78 of 100
# Training
# 16it [00:04,  3.36it/s]
# Validating
# 16it [00:03,  4.05it/s]
# Train Loss: 0.0404, Train Acc: 98.39
# Val Loss: 1.0718, Val Acc: 76.00
# Epoch 79 of 100
# Training
# 16it [00:04,  3.35it/s]
# Validating
# 16it [00:03,  4.64it/s]
# Train Loss: 0.0602, Train Acc: 98.59
# Val Loss: 1.0400, Val Acc: 76.00
# Epoch 80 of 100
# Training
# 16it [00:04,  3.28it/s]
# Validating
# 16it [00:03,  4.65it/s]
# Train Loss: 0.0523, Train Acc: 98.39
# Val Loss: 1.0643, Val Acc: 74.00
# Epoch 81 of 100
# Training
# 16it [00:04,  3.36it/s]
# Validating
# 16it [00:03,  4.07it/s]
# Train Loss: 0.0802, Train Acc: 97.79
# Val Loss: 1.0885, Val Acc: 77.00
# Epoch 82 of 100
# Training
# 16it [00:04,  3.37it/s]
# Validating
# 16it [00:03,  4.67it/s]
# Train Loss: 0.0359, Train Acc: 98.59
# Val Loss: 1.0994, Val Acc: 73.20
# Epoch 83 of 100
# Training
# 16it [00:04,  3.24it/s]
# Validating
# 16it [00:03,  4.64it/s]
# Train Loss: 0.0787, Train Acc: 97.19
# Val Loss: 0.8252, Val Acc: 78.40
# Epoch 84 of 100
# Training
# 16it [00:04,  3.33it/s]
# Validating
# 16it [00:03,  4.28it/s]
# Train Loss: 0.0965, Train Acc: 95.98
# Val Loss: 1.2167, Val Acc: 70.00
# Epoch 85 of 100
# Training
# 16it [00:04,  3.36it/s]
# Validating
# 16it [00:03,  4.44it/s]
# Train Loss: 0.0804, Train Acc: 97.59
# Val Loss: 0.9280, Val Acc: 77.80
# Epoch 86 of 100
# Training
# 16it [00:04,  3.21it/s]
# Validating
# 16it [00:03,  4.68it/s]
# Train Loss: 0.0489, Train Acc: 98.39
# Val Loss: 0.7975, Val Acc: 78.80
# Epoch 87 of 100
# Training
# 16it [00:04,  3.27it/s]
# Validating
# 16it [00:03,  4.60it/s]
# Train Loss: 0.0756, Train Acc: 97.59
# Val Loss: 1.1875, Val Acc: 71.00
# Epoch 88 of 100
# Training
# 16it [00:04,  3.36it/s]
# Validating
# 16it [00:03,  4.15it/s]
# Train Loss: 0.0536, Train Acc: 98.80
# Val Loss: 1.2594, Val Acc: 69.80
# Epoch 89 of 100
# Training
# 16it [00:04,  3.31it/s]
# Validating
# 16it [00:03,  4.73it/s]
# Train Loss: 0.0761, Train Acc: 97.39
# Val Loss: 0.8761, Val Acc: 76.60
# Epoch 90 of 100
# Training
# 16it [00:04,  3.25it/s]
# Validating
# 16it [00:03,  4.69it/s]
# Train Loss: 0.0306, Train Acc: 99.00
# Val Loss: 0.8083, Val Acc: 75.80
# Epoch 91 of 100
# Training
# 16it [00:04,  3.36it/s]
# Validating
# 16it [00:03,  4.05it/s]
# Train Loss: 0.0135, Train Acc: 99.60
# Val Loss: 0.6623, Val Acc: 79.20
# Epoch 92 of 100
# Training
# 16it [00:04,  3.35it/s]
# Validating
# 16it [00:03,  4.73it/s]
# Train Loss: 0.0177, Train Acc: 99.60
# Val Loss: 1.0355, Val Acc: 75.60
# Epoch 93 of 100
# Training
# 16it [00:04,  3.27it/s]
# Validating
# 16it [00:03,  4.67it/s]
# Train Loss: 0.0073, Train Acc: 100.00
# Val Loss: 0.8251, Val Acc: 77.20
# Epoch 94 of 100
# Training
# 16it [00:04,  3.36it/s]
# Validating
# 16it [00:03,  4.01it/s]
# Train Loss: 0.0430, Train Acc: 99.00
# Val Loss: 1.3569, Val Acc: 71.00
# Epoch 95 of 100
# Training
# 16it [00:04,  3.36it/s]
# Validating
# 16it [00:03,  4.71it/s]
# Train Loss: 0.1529, Train Acc: 94.98
# Val Loss: 1.1647, Val Acc: 78.00
# Epoch 96 of 100
# Training
# 16it [00:04,  3.25it/s]
# Validating
# 16it [00:03,  4.70it/s]
# Train Loss: 0.0762, Train Acc: 97.59
# Val Loss: 0.9477, Val Acc: 72.00
# Epoch 97 of 100
# Training
# 16it [00:04,  3.34it/s]
# Validating
# 16it [00:03,  4.18it/s]
# Train Loss: 0.0422, Train Acc: 98.59
# Val Loss: 0.9759, Val Acc: 76.60
# Epoch 98 of 100
# Training
# 16it [00:04,  3.36it/s]
# Validating
# 16it [00:03,  4.47it/s]
# Train Loss: 0.0285, Train Acc: 99.00
# Val Loss: 0.7872, Val Acc: 80.00
# Epoch 99 of 100
# Training
# 16it [00:04,  3.25it/s]
# Validating
# 16it [00:03,  4.76it/s]
# Train Loss: 0.0108, Train Acc: 99.60
# Val Loss: 0.8401, Val Acc: 78.80
# Epoch 100 of 100
# Training
# 16it [00:04,  3.31it/s]
# Validating
# 16it [00:03,  4.46it/s]
# Train Loss: 0.0263, Train Acc: 98.80
# Val Loss: 1.3498, Val Acc: 74.00
# Training time: 13.988 minutes

# %%
plt.figure(figsize=(10, 7))
plt.plot(train_accuracy, color='green', label='train accuracy')
plt.plot(val_accuracy, color='blue', label='validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig(f"/content/chap08/img/{acc_plot_name}.png")
plt.show()

plt.figure(figsize=(10, 7))
plt.plot(train_loss, color='orange', label='train loss')
plt.plot(val_loss, color='red', label='validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig(f"content/chap08/img/{loss_plot_name}.png")
plt.show()

print('Saving model...')
torch.save(model.state_dict(), f"content/chap08/img/{model_name}.pth")
print('TRAINING COMPLETE')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-19-236579576.py in <cell line: 0>()
#      14 plt.ylabel('Loss')
#      15 plt.legend()
# ---> 16 plt.savefig(f"content/chap08/img/{loss_plot_name}.png")
#      17 plt.show()
#      18
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#    1241     # savefig default implementation has no return, so mypy is unhappy
#    1242     # presumably this is here because subclasses can return?
# -> 1243     res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1244     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1245     return res
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    3488                 for ax in self.axes:
#    3489                     _recursively_make_axes_transparent(stack, ax)
# -> 3490             self.canvas.print_figure(fname, **kwargs)
#    3491
#    3492     def ginput(self, n=1, timeout=30, show_clicks=True,
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2182                 # force the figure dpi to 72), so we need to set it again here.
#    2183                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2184                     result = print_method(
#    2185                         filename,
#    2186                         facecolor=facecolor,
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backend_bases.py in <lambda>(*args, **kwargs)
#    2038                 "bbox_inches_restore"}
#    2039             skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2040             print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2041                 *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2042         else:  # Let third-parties do as they see fit.
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs)
#     479             *metadata*, including the default 'Software' key.
#     480         """
# --> 481         self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#     482
#     483     def print_to_buffer(self):
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backends/backend_agg.py in _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     428         """
#     429         FigureCanvasAgg.draw(self)
# --> 430         mpl.image.imsave(
#     431             filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     432             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1632         pil_kwargs.setdefault("format", format)
#    1633         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1634         image.save(fname, **pil_kwargs)
#    1635
#    1636
#
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py in save(self, fp, format, **params)
#    2574                 fp = builtins.open(filename, "r+b")
#    2575             else:
# -> 2576                 fp = builtins.open(filename, "w+b")
#    2577         else:
#    2578             fp = cast(IO[bytes], fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'content/chap08/img/loss.png'
